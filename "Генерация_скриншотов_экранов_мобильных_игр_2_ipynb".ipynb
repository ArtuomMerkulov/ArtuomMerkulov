# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtuomMerkulov/ArtuomMerkulov/blob/main/%22%D0%93%D0%B5%D0%BD%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D1%8F_%D1%81%D0%BA%D1%80%D0%B8%D0%BD%D1%88%D0%BE%D1%82%D0%BE%D0%B2_%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%BE%D0%B2_%D0%BC%D0%BE%D0%B1%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D0%B3%D1%80_2_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Генерация скриншотов экранов мобильных игр
# Для генерации использовал маску в качестве условия

# %%
# !pip install keras==2.0 -q 
# !pip install tensorflow==2.7.0 -q
# Out:
#      |████████████████████████████████| 5.9 MB 24.3 MB/s
#      |████████████████████████████████| 458.4 MB 19 kB/s
#      |████████████████████████████████| 458.4 MB 32 kB/s
#      |████████████████████████████████| 460.4 MB 38 kB/s
#      |████████████████████████████████| 1.2 MB 53.1 MB/s
#      |████████████████████████████████| 4.0 MB 56.5 MB/s
#      |████████████████████████████████| 462 kB 73.3 MB/s
#   Building wheel for keras (setup.py) ... done
#   Building wheel for termcolor (setup.py) ... done
#   Building wheel for wrapt (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# pydantic 1.10.2 requires typing-extensions>=4.1.0, but you have typing-extensions 3.7.4.3 which is incompatible.
# jaxlib 0.3.25+cuda11.cudnn805 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# jax 0.3.25 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# grpcio-status 1.48.2 requires grpcio>=1.48.2, but you have grpcio 1.34.1 which is incompatible.
# google-cloud-bigquery 3.3.6 requires grpcio<2.0dev,>=1.47.0, but you have grpcio 1.34.1 which is incompatible.
# cupy-cuda11x 11.0.0 requires numpy<1.26,>=1.20, but you have numpy 1.19.5 which is incompatible.
# cmdstanpy 1.0.8 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.

# %%
import scipy
import tensorflow as tf

from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate, LeakyReLU
from keras.layers import BatchNormalization, Add, add
from keras.layers import UpSampling2D, Conv2D
from keras.applications import vgg19
#from keras.utils import plot_model
from tensorflow.keras.utils import plot_model
#from tensorflow.keras.preprocessing.image import img_to_array, load_img
from keras.preprocessing.image import img_to_array, load_img
#from keras.models import Sequential, Model
from keras.models import Sequential, Model
#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
import os
import keras.backend as K
from tqdm import tqdm
from tensorflow.python.platform.tf_logging import set_verbosity, FATAL
set_verbosity(FATAL)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '0'

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unrar x '/content/drive/MyDrive/Numpy/Mоbile game loading screen.rar'
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/Numpy/Mоbile game loading screen.rar
#
#
# Would you like to replace the existing file Mоbile game loading screen/1010!.jpg
#  40625 bytes, modified on 2021-06-24 06:41
# with a new one
#  40625 bytes, modified on 2021-06-24 06:41
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit A
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
img_shape = (128, 256, 3) #размер изображения
height = img_shape[0]
width = img_shape[1]

# %%
imgs = [] 
for image in sorted(os.listdir('/content/Mоbile game loading screen/')): #проходим по каждому файлу, получив список файлов в папке 
  print(image)
  imgs.append(img_to_array(load_img('/content/Mоbile game loading screen/'+image, target_size=(height,width)))) #загружаем файл, устанавливаем нужный размер и сохраняем в оперативную память, как массив numpy
imgs = np.stack(imgs).astype('uint8') #сохраняем итоговый массив изображений

masks = []
for image in sorted(os.listdir('/content/Mоbile game loading screen/')): #проходим по каждому файлу, получив список файлов в папке 
  masks.append(img_to_array(load_img('/content/Mоbile game loading screen/'+image, target_size=(height,width)))) #загружаем файл, устанавливаем нужный размер и сохраняем в оперативную память, как массив numpy
masks = np.stack(masks).astype('uint8') #сохраняем итоговый массив масок
# Out:
# 1010!.jpg
# 8 Ball pool.jpg
# Amaze.jpg
# Animal transform race.jpg
# Ball brick breaker.jpg
# Beat racing.jpg
# Billiards city.jpg
# Blob runner 3d.jpg
# Bob's world.jpg
# Body race.jpg
# Bottle flip 3d.jpg
# Brawl Stars.png
# Bridal Rush!.jpg
# Bridge race.jpg
# Call of duty mobile.jpg
# Cannon shot.jpg
# Carpet roller - dress and rugs.jpg
# Castle clash.png
# Cheerleader run 3d.jpg
# Clash of clans.jpg
# Color crush.jpg
# Colour adventure.jpg
# Comics Bob.jpg
# Cut and paint.jpg
# Dancing line origins.jpg
# Dancing road.jpg
# Delete puzzle.jpg
# Draw it story.jpg
# Draw joust.jpg
# Drop number.jpg
# Dunk shot.jpg
# Epic race 3d.jpg
# Fidget toys 3d.jpg
# Fruit Block - puzzle legend.jpg
# Fun race 3d.jpg
# Galaxy attack alien shooter.jpg
# GardenScapes.jpg
# Giant rush.jpg
# Going balls.jpg
# Golf blitz.jpg
# Heel master.jpg
# Helix stack jump.jpg
# Hide 'N seek.jpg
# Hit Master 3d.jpg
# Hit and knock down.jpg
# Home pin - how to loot.jpg
# Homescapes.jpeg
# Hop Ball 3.jpg
# IdleAnts.jpg
# Jelly shift.jpg
# Johnny Trigger.jpg
# Join and clash.jpg
# Join and strike.jpg
# Kick the Buddy.jpg
# Magic tiles 3.jpg
# Merge Block 3d.jpg
# Moto X3M.jpg
# Muscle rush.jpg
# Paper fold.jpg
# Paper's grade please!.jpg
# Pencil Rush 3d.jpg
# Perfect cream.jpg
# Pick me up 3d.jpg
# Plants vs zombies.jpg
# Player Unknow's Battlegrounds mobile.jpg
# Ramp car jumping.jpg
# Red Ball 4.jpg
# Rider.jpg
# Rocket punch.jpg
# Roof rails.jpg
# Rope slash.jpg
# Shooting ball.jpg
# Shortcut run.jpg
# Sky roller.jpg
# Sling drift.jpg
# Smash colors 3d.jpg
# Soap cutting.jpg
# Sort People Puzzle.jpg
# Spiral roll.jpg
# Stack colors.jpg
# Stack rider.jpg
# Stacky dash.jpg
# Standoff 2.jpg
# Stealth master.jpg
# Stickman Hook.jpg
# Sushi roll 3d.jpg
# Sword play.jpg
# Tangle Master 3d.jpg
# Tank stars.jpg
# Taxi run.jpg
# Tile Master 3d.jpg
# Tiles hop.jpg
# Zen idle - gravity meditation.jpg
# hill climb racing 2.jpg
# hill climb racing.jpg
# Долина сладостей.jpg
# Сальто к вершине.jpg
# Слияние мастера.jpg
# Слова из слова.jpg
# Туземцы.jpg

# %%
def build_generator():
    gf = 64 #минимальное число фильтров
    
    def conv2d(layer_input, filters, f_size=4, bn=True): #слой с понижением разрешения (encoder)
        
        d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input) #strides = 2 уменьшает разрешение в 2 раза при padding='same'
        d = LeakyReLU(alpha=0.2)(d)
        if bn:
            d = BatchNormalization(momentum=0.8)(d)
        return d

    def deconv2d(layer_input, skip_input, filters, f_size=4, dropout_rate=0): #слой с повышением разрешения (decoder) принимает на вход предыдущий слой и skip-слой от encoder'а
        u = UpSampling2D(size=2)(layer_input) #увеличивам разрешение в 2 раза
        u = Conv2D(filters, kernel_size=f_size, strides=1, padding='same', activation='relu')(u) #strides=1, padding='same',  поэтому разрешение сохраняется
        if dropout_rate:
            u = Dropout(dropout_rate)(u)
        u = BatchNormalization(momentum=0.8)(u)
        u = Concatenate()([u, skip_input]) #соединяем skip-слой и слой decoder'а
        return u

    d0 = Input(shape=img_shape, name="condition") #входное изображение (условие)

    # Часть encoder'a
    d1 = conv2d(d0, gf, bn=False)
    d2 = conv2d(d1, gf*2)
    d3 = conv2d(d2, gf*4) #чем меньше размер карт активаций
    d4 = conv2d(d3, gf*8) #тем больше должно быть фильтров в сверточном слое
    d5 = conv2d(d4, gf*8)
    d6 = conv2d(d5, gf*8)
    d7 = conv2d(d6, gf*8)

    # Часть decoder'a
    u1 = deconv2d(d7, d6, gf*8)
    u2 = deconv2d(u1, d5, gf*8) 
    u3 = deconv2d(u2, d4, gf*8) #чем больше размер карт активаций
    u4 = deconv2d(u3, d3, gf*4) #тем меньше должно быть фильтров в сверточном слое
    u5 = deconv2d(u4, d2, gf*2)
    u6 = deconv2d(u5, d1, gf)

    u7 = UpSampling2D(size=2)(u6)
    output_img = Conv2D(3, kernel_size=4, strides=1, padding='same', activation='tanh', name='G_output')(u7) 

    return Model(d0, output_img, name="G")

# %%
gen = build_generator() #создаем генератор
gen.summary()
# Out:
# Model: "G"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  condition (InputLayer)         [(None, 128, 256, 3  0           []
#                                 )]
#
#  conv2d_34 (Conv2D)             (None, 64, 128, 64)  3136        ['condition[0][0]']
#
#  leaky_re_lu_22 (LeakyReLU)     (None, 64, 128, 64)  0           ['conv2d_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 64, 128)  131200      ['leaky_re_lu_22[0][0]']
#
#  leaky_re_lu_23 (LeakyReLU)     (None, 32, 64, 128)  0           ['conv2d_35[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 64, 128)  512        ['leaky_re_lu_23[0][0]']
#  ormalization)
#
#  conv2d_36 (Conv2D)             (None, 16, 32, 256)  524544      ['batch_normalization_30[0][0]']
#
#  leaky_re_lu_24 (LeakyReLU)     (None, 16, 32, 256)  0           ['conv2d_36[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 32, 256)  1024       ['leaky_re_lu_24[0][0]']
#  ormalization)
#
#  conv2d_37 (Conv2D)             (None, 8, 16, 512)   2097664     ['batch_normalization_31[0][0]']
#
#  leaky_re_lu_25 (LeakyReLU)     (None, 8, 16, 512)   0           ['conv2d_37[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 16, 512)  2048        ['leaky_re_lu_25[0][0]']
#  ormalization)
#
#  conv2d_38 (Conv2D)             (None, 4, 8, 512)    4194816     ['batch_normalization_32[0][0]']
#
#  leaky_re_lu_26 (LeakyReLU)     (None, 4, 8, 512)    0           ['conv2d_38[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 4, 8, 512)   2048        ['leaky_re_lu_26[0][0]']
#  ormalization)
#
#  conv2d_39 (Conv2D)             (None, 2, 4, 512)    4194816     ['batch_normalization_33[0][0]']
#
#  leaky_re_lu_27 (LeakyReLU)     (None, 2, 4, 512)    0           ['conv2d_39[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 2, 4, 512)   2048        ['leaky_re_lu_27[0][0]']
#  ormalization)
#
#  conv2d_40 (Conv2D)             (None, 1, 2, 512)    4194816     ['batch_normalization_34[0][0]']
#
#  leaky_re_lu_28 (LeakyReLU)     (None, 1, 2, 512)    0           ['conv2d_40[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 1, 2, 512)   2048        ['leaky_re_lu_28[0][0]']
#  ormalization)
#
#  up_sampling2d_14 (UpSampling2D  (None, 2, 4, 512)   0           ['batch_normalization_35[0][0]']
#  )
#
#  conv2d_41 (Conv2D)             (None, 2, 4, 512)    4194816     ['up_sampling2d_14[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 2, 4, 512)   2048        ['conv2d_41[0][0]']
#  ormalization)
#
#  concatenate_14 (Concatenate)   (None, 2, 4, 1024)   0           ['batch_normalization_36[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  up_sampling2d_15 (UpSampling2D  (None, 4, 8, 1024)  0           ['concatenate_14[0][0]']
#  )
#
#  conv2d_42 (Conv2D)             (None, 4, 8, 512)    8389120     ['up_sampling2d_15[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 4, 8, 512)   2048        ['conv2d_42[0][0]']
#  ormalization)
#
#  concatenate_15 (Concatenate)   (None, 4, 8, 1024)   0           ['batch_normalization_37[0][0]',
#                                                                   'batch_normalization_33[0][0]']
#
#  up_sampling2d_16 (UpSampling2D  (None, 8, 16, 1024)  0          ['concatenate_15[0][0]']
#  )
#
#  conv2d_43 (Conv2D)             (None, 8, 16, 512)   8389120     ['up_sampling2d_16[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 16, 512)  2048        ['conv2d_43[0][0]']
#  ormalization)
#
#  concatenate_16 (Concatenate)   (None, 8, 16, 1024)  0           ['batch_normalization_38[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  up_sampling2d_17 (UpSampling2D  (None, 16, 32, 1024  0          ['concatenate_16[0][0]']
#  )                              )
#
#  conv2d_44 (Conv2D)             (None, 16, 32, 256)  4194560     ['up_sampling2d_17[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 16, 32, 256)  1024       ['conv2d_44[0][0]']
#  ormalization)
#
#  concatenate_17 (Concatenate)   (None, 16, 32, 512)  0           ['batch_normalization_39[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  up_sampling2d_18 (UpSampling2D  (None, 32, 64, 512)  0          ['concatenate_17[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 32, 64, 128)  1048704     ['up_sampling2d_18[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 32, 64, 128)  512        ['conv2d_45[0][0]']
#  ormalization)
#
#  concatenate_18 (Concatenate)   (None, 32, 64, 256)  0           ['batch_normalization_40[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  up_sampling2d_19 (UpSampling2D  (None, 64, 128, 256  0          ['concatenate_18[0][0]']
#  )                              )
#
#  conv2d_46 (Conv2D)             (None, 64, 128, 64)  262208      ['up_sampling2d_19[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 64, 128, 64)  256        ['conv2d_46[0][0]']
#  ormalization)
#
#  concatenate_19 (Concatenate)   (None, 64, 128, 128  0           ['batch_normalization_41[0][0]',
#                                 )                                 'leaky_re_lu_22[0][0]']
#
#  up_sampling2d_20 (UpSampling2D  (None, 128, 256, 12  0          ['concatenate_19[0][0]']
#  )                              8)
#
#  G_output (Conv2D)              (None, 128, 256, 3)  6147        ['up_sampling2d_20[0][0]']
#
# ==================================================================================================
# Total params: 41,843,331
# Trainable params: 41,834,499
# Non-trainable params: 8,832
# __________________________________________________________________________________________________

# %%
def build_discriminator():
  
  df = 64 #минимальное число фильтров
  def d_layer(layer_input, filters, f_size=4, bn=True): #слой дискриминатора с понижением разрешения
      
      d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input) #размер карт активаций будет уменьшен в 2 раза, так как strides=2 при padding='same'
      d = LeakyReLU(alpha=0.2)(d)
      if bn:
          d = BatchNormalization(momentum=0.8)(d)
      return d

  image = Input(shape=img_shape, name="real_or_fake_A") #на вход дискриминатору подается либо реальное изображение, либо фейковое
  condition = Input(shape=img_shape, name="condition") #и дополнительно изображение-условие

  combined_imgs = Concatenate(axis=-1)([image, condition]) #объединяем оба входа в 1 слой

  d1 = d_layer(combined_imgs, df, bn=False)
  d2 = d_layer(d1, df*2)
  d3 = d_layer(d2, df*4) #уменьшаем размер карт активации, увеличивая их число
  d4 = d_layer(d3, df*8)

  validity = Conv2D(1, kernel_size=4, strides=1, padding='same', name='D_output', activation='sigmoid')(d4) #на выходе будет двумерный массив, каждый элемент которого определяет, подлинность части изображения (patch GAN)
                                                                                                            #0 отвечает за фейковые изображения, 1 за подлинные, поэтому используем sigmoid

  return Model([image, condition], validity, name='D')

# %%
dis = build_discriminator()
dis.summary()
# Out:
# Model: "D"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  real_or_fake_A (InputLayer)    [(None, 128, 256, 3  0           []
#                                 )]
#
#  condition (InputLayer)         [(None, 128, 256, 3  0           []
#                                 )]
#
#  concatenate_20 (Concatenate)   (None, 128, 256, 6)  0           ['real_or_fake_A[0][0]',
#                                                                   'condition[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 64, 128, 64)  6208        ['concatenate_20[0][0]']
#
#  leaky_re_lu_29 (LeakyReLU)     (None, 64, 128, 64)  0           ['conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 32, 64, 128)  131200      ['leaky_re_lu_29[0][0]']
#
#  leaky_re_lu_30 (LeakyReLU)     (None, 32, 64, 128)  0           ['conv2d_48[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 32, 64, 128)  512        ['leaky_re_lu_30[0][0]']
#  ormalization)
#
#  conv2d_49 (Conv2D)             (None, 16, 32, 256)  524544      ['batch_normalization_42[0][0]']
#
#  leaky_re_lu_31 (LeakyReLU)     (None, 16, 32, 256)  0           ['conv2d_49[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16, 32, 256)  1024       ['leaky_re_lu_31[0][0]']
#  ormalization)
#
#  conv2d_50 (Conv2D)             (None, 8, 16, 512)   2097664     ['batch_normalization_43[0][0]']
#
#  leaky_re_lu_32 (LeakyReLU)     (None, 8, 16, 512)   0           ['conv2d_50[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 16, 512)  2048        ['leaky_re_lu_32[0][0]']
#  ormalization)
#
#  D_output (Conv2D)              (None, 8, 16, 1)     8193        ['batch_normalization_44[0][0]']
#
# ==================================================================================================
# Total params: 2,771,393
# Trainable params: 2,769,601
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
def build_vgg():
  #для feature loss создаем vgg модель
  vgg_in = Input(img_shape)
  vgg = vgg19.VGG19(include_top=False, input_shape=img_shape, input_tensor=vgg_in) #скачиваем архитектуру и веса 
  vgg_out = vgg.get_layer('block5_conv4').output #получаем последний сверточный слой
  vgg = Model(vgg_in, vgg_out, name='vgg')
  vgg.trainable = False #модель уже предобучена, поэтому ее необходимо заморозить

  return vgg

# %%
vgg = build_vgg()
vgg.summary()
# Out:
# Model: "vgg"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 128, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 128, 64)       0
#
#  block2_conv1 (Conv2D)       (None, 64, 128, 128)      73856
#
#  block2_conv2 (Conv2D)       (None, 64, 128, 128)      147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 16, 512)        0
#
#  block5_conv1 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv4 (Conv2D)       (None, 8, 16, 512)        2359808
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
def build_gan(generator, discriminator, vgg):
  discriminator.trainable = False #замораживаем дискриминатор

  condition = Input(img_shape, name='Condition') #вход изображения-условия
  fake_img = generator(condition) #изображение, полученное от генератора

  fake_features = vgg(fake_img) #карты активации, полученные от фейкового изображения

  fake_validity = discriminator([fake_img, condition]) #соединяем генератор и дискриминатор

  gan = Model(condition, [fake_validity, fake_img, fake_features]) #получаем gan с тремя выходами: первый отвечает за "правдоподобность", второй за изображение от генератора, третий за карты активации

  return gan

# %%
dis.output_shape[1:]
# Out:
# (8, 16, 1)

# %%
(np.ones((128, *dis.output_shape[1:]))).shape
# Out:
# (128, 8, 16, 1)

# %%
def train(generator, discriminator, gan, vgg, imgs, masks, epochs, batch_size):

  for epoch in range(epochs): 
    idx = np.random.choice(imgs.shape[0], imgs.shape[0], replace=False) #перемешиваем индексы, чтобы batch'и всегда были разными

    with tqdm(total=imgs.shape[0]) as pbar: #для отслеживания создаем progressbar
      for batch in range(imgs.shape[0]//batch_size):
        
        #для тренировки дискриминатора применяем label smoothing
        #размерность Y: (размер батча, высота последнего слоя дискриминатора, ширина, 1)
        y_real = np.ones((batch_size, *discriminator.output_shape[1:])) - np.random.random_sample((batch_size, *discriminator.output_shape[1:]))*0.2
        y_fake = np.random.random_sample((batch_size, *discriminator.output_shape[1:]))*0.2

        idx_batch = idx[batch*batch_size:(batch+1)*batch_size] #получаем индексы для одного batch'а

        real_imgs = (imgs[idx_batch]/127.5)-1 #получаем истинные изображения и нормализуем их
        condition = (masks[idx_batch]/127.5)-1 #получаем маски и нормализуем их

        fake_imgs = generator.predict(condition) #генерируем изображения по маскам

        #тренируем дискриминатор       
        d_loss_real = discriminator.train_on_batch([real_imgs, condition], y_real)
        d_loss_fake = discriminator.train_on_batch([fake_imgs, condition], y_fake)
        d_loss_total = 0.5*np.add(d_loss_real, d_loss_fake)
   
        #тренируем генератор
        real_features = vgg.predict(real_imgs)
        y_real = np.ones((batch_size, *discriminator.output_shape[1:]))

        g_loss = gan.train_on_batch(condition, [y_real, real_imgs, real_features])
        pbar.update(batch_size) #обновляем progressbar
        pbar.set_description("Epoch: {}/{}, Discriminator loss: {}, Generator loss:{}".format(epoch+1, epochs, d_loss_total[0], g_loss))

# %%
gen = build_generator() #создаем генератор

dis = build_discriminator() #создаем дискриминатор
dis.compile(loss='binary_crossentropy', optimizer=Adam(lr=1e-4, beta_1=0.5), metrics=['accuracy'])

vgg = build_vgg() #создаем vgg модель

gan = build_gan(gen, dis, vgg) #создаем gan
gan.compile(loss=['binary_crossentropy', 'mse', 'mse'], loss_weights=[1,100,10], optimizer=Adam(lr=1e-4, beta_1=0.5)) #вклад разницы между пикселями в 10 раз больше, чем вклад от feature loss и в 100 раз больше, чем вклад от GAN
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
gen.summary()
# Out:
# Model: "G"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  condition (InputLayer)         [(None, 128, 256, 3  0           []
#                                 )]
#
#  conv2d_51 (Conv2D)             (None, 64, 128, 64)  3136        ['condition[0][0]']
#
#  leaky_re_lu_33 (LeakyReLU)     (None, 64, 128, 64)  0           ['conv2d_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 32, 64, 128)  131200      ['leaky_re_lu_33[0][0]']
#
#  leaky_re_lu_34 (LeakyReLU)     (None, 32, 64, 128)  0           ['conv2d_52[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 32, 64, 128)  512        ['leaky_re_lu_34[0][0]']
#  ormalization)
#
#  conv2d_53 (Conv2D)             (None, 16, 32, 256)  524544      ['batch_normalization_45[0][0]']
#
#  leaky_re_lu_35 (LeakyReLU)     (None, 16, 32, 256)  0           ['conv2d_53[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 16, 32, 256)  1024       ['leaky_re_lu_35[0][0]']
#  ormalization)
#
#  conv2d_54 (Conv2D)             (None, 8, 16, 512)   2097664     ['batch_normalization_46[0][0]']
#
#  leaky_re_lu_36 (LeakyReLU)     (None, 8, 16, 512)   0           ['conv2d_54[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 8, 16, 512)  2048        ['leaky_re_lu_36[0][0]']
#  ormalization)
#
#  conv2d_55 (Conv2D)             (None, 4, 8, 512)    4194816     ['batch_normalization_47[0][0]']
#
#  leaky_re_lu_37 (LeakyReLU)     (None, 4, 8, 512)    0           ['conv2d_55[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 4, 8, 512)   2048        ['leaky_re_lu_37[0][0]']
#  ormalization)
#
#  conv2d_56 (Conv2D)             (None, 2, 4, 512)    4194816     ['batch_normalization_48[0][0]']
#
#  leaky_re_lu_38 (LeakyReLU)     (None, 2, 4, 512)    0           ['conv2d_56[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 2, 4, 512)   2048        ['leaky_re_lu_38[0][0]']
#  ormalization)
#
#  conv2d_57 (Conv2D)             (None, 1, 2, 512)    4194816     ['batch_normalization_49[0][0]']
#
#  leaky_re_lu_39 (LeakyReLU)     (None, 1, 2, 512)    0           ['conv2d_57[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 1, 2, 512)   2048        ['leaky_re_lu_39[0][0]']
#  ormalization)
#
#  up_sampling2d_21 (UpSampling2D  (None, 2, 4, 512)   0           ['batch_normalization_50[0][0]']
#  )
#
#  conv2d_58 (Conv2D)             (None, 2, 4, 512)    4194816     ['up_sampling2d_21[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 2, 4, 512)   2048        ['conv2d_58[0][0]']
#  ormalization)
#
#  concatenate_21 (Concatenate)   (None, 2, 4, 1024)   0           ['batch_normalization_51[0][0]',
#                                                                   'batch_normalization_49[0][0]']
#
#  up_sampling2d_22 (UpSampling2D  (None, 4, 8, 1024)  0           ['concatenate_21[0][0]']
#  )
#
#  conv2d_59 (Conv2D)             (None, 4, 8, 512)    8389120     ['up_sampling2d_22[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 4, 8, 512)   2048        ['conv2d_59[0][0]']
#  ormalization)
#
#  concatenate_22 (Concatenate)   (None, 4, 8, 1024)   0           ['batch_normalization_52[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  up_sampling2d_23 (UpSampling2D  (None, 8, 16, 1024)  0          ['concatenate_22[0][0]']
#  )
#
#  conv2d_60 (Conv2D)             (None, 8, 16, 512)   8389120     ['up_sampling2d_23[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 8, 16, 512)  2048        ['conv2d_60[0][0]']
#  ormalization)
#
#  concatenate_23 (Concatenate)   (None, 8, 16, 1024)  0           ['batch_normalization_53[0][0]',
#                                                                   'batch_normalization_47[0][0]']
#
#  up_sampling2d_24 (UpSampling2D  (None, 16, 32, 1024  0          ['concatenate_23[0][0]']
#  )                              )
#
#  conv2d_61 (Conv2D)             (None, 16, 32, 256)  4194560     ['up_sampling2d_24[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 16, 32, 256)  1024       ['conv2d_61[0][0]']
#  ormalization)
#
#  concatenate_24 (Concatenate)   (None, 16, 32, 512)  0           ['batch_normalization_54[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  up_sampling2d_25 (UpSampling2D  (None, 32, 64, 512)  0          ['concatenate_24[0][0]']
#  )
#
#  conv2d_62 (Conv2D)             (None, 32, 64, 128)  1048704     ['up_sampling2d_25[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 32, 64, 128)  512        ['conv2d_62[0][0]']
#  ormalization)
#
#  concatenate_25 (Concatenate)   (None, 32, 64, 256)  0           ['batch_normalization_55[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  up_sampling2d_26 (UpSampling2D  (None, 64, 128, 256  0          ['concatenate_25[0][0]']
#  )                              )
#
#  conv2d_63 (Conv2D)             (None, 64, 128, 64)  262208      ['up_sampling2d_26[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 64, 128, 64)  256        ['conv2d_63[0][0]']
#  ormalization)
#
#  concatenate_26 (Concatenate)   (None, 64, 128, 128  0           ['batch_normalization_56[0][0]',
#                                 )                                 'leaky_re_lu_33[0][0]']
#
#  up_sampling2d_27 (UpSampling2D  (None, 128, 256, 12  0          ['concatenate_26[0][0]']
#  )                              8)
#
#  G_output (Conv2D)              (None, 128, 256, 3)  6147        ['up_sampling2d_27[0][0]']
#
# ==================================================================================================
# Total params: 41,843,331
# Trainable params: 41,834,499
# Non-trainable params: 8,832
# __________________________________________________________________________________________________

# %%
dis.summary()
# Out:
# Model: "D"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  real_or_fake_A (InputLayer)    [(None, 128, 256, 3  0           []
#                                 )]
#
#  condition (InputLayer)         [(None, 128, 256, 3  0           []
#                                 )]
#
#  concatenate_27 (Concatenate)   (None, 128, 256, 6)  0           ['real_or_fake_A[0][0]',
#                                                                   'condition[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 64, 128, 64)  6208        ['concatenate_27[0][0]']
#
#  leaky_re_lu_40 (LeakyReLU)     (None, 64, 128, 64)  0           ['conv2d_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 32, 64, 128)  131200      ['leaky_re_lu_40[0][0]']
#
#  leaky_re_lu_41 (LeakyReLU)     (None, 32, 64, 128)  0           ['conv2d_65[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 32, 64, 128)  512        ['leaky_re_lu_41[0][0]']
#  ormalization)
#
#  conv2d_66 (Conv2D)             (None, 16, 32, 256)  524544      ['batch_normalization_57[0][0]']
#
#  leaky_re_lu_42 (LeakyReLU)     (None, 16, 32, 256)  0           ['conv2d_66[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 16, 32, 256)  1024       ['leaky_re_lu_42[0][0]']
#  ormalization)
#
#  conv2d_67 (Conv2D)             (None, 8, 16, 512)   2097664     ['batch_normalization_58[0][0]']
#
#  leaky_re_lu_43 (LeakyReLU)     (None, 8, 16, 512)   0           ['conv2d_67[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 8, 16, 512)  2048        ['leaky_re_lu_43[0][0]']
#  ormalization)
#
#  D_output (Conv2D)              (None, 8, 16, 1)     8193        ['batch_normalization_59[0][0]']
#
# ==================================================================================================
# Total params: 2,771,393
# Trainable params: 0
# Non-trainable params: 2,771,393
# __________________________________________________________________________________________________

# %%
vgg.summary()
# Out:
# Model: "vgg"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 128, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 128, 64)       0
#
#  block2_conv1 (Conv2D)       (None, 64, 128, 128)      73856
#
#  block2_conv2 (Conv2D)       (None, 64, 128, 128)      147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 16, 512)        0
#
#  block5_conv1 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv4 (Conv2D)       (None, 8, 16, 512)        2359808
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
train(gen, dis, gan, vgg, imgs, masks, 100, 100)
# Out:
# Epoch: 1/100, Discriminator loss: 1.0038698613643646, Generator loss:[122.28921508789062, 0.6618092060089111, 1.207296371459961, 0.08977766335010529]: 100%|██████████| 100/100 [00:08<00:00, 11.55it/s]
# Epoch: 2/100, Discriminator loss: 1.3518618941307068, Generator loss:[29.534082412719727, 0.7014983296394348, 0.28080734610557556, 0.07518500089645386]: 100%|██████████| 100/100 [00:04<00:00, 22.66it/s]
# Epoch: 91/100, Discriminator loss: 0.6904290616512299, Generator loss:[3.9790737628936768, 0.7956022620201111, 0.029433652758598328, 0.024010609835386276]: 100%|██████████| 100/100 [00:04<00:00, 21.90it/s]
# Epoch: 92/100, Discriminator loss: 0.6860502660274506, Generator loss:[3.9443154335021973, 0.7762017250061035, 0.02930355817079544, 0.023775780573487282]: 100%|██████████| 100/100 [00:04<00:00, 22.32it/s]
# Epoch: 93/100, Discriminator loss: 0.6797414124011993, Generator loss:[3.9330203533172607, 0.7807972431182861, 0.029164286330342293, 0.02357945218682289]: 100%|██████████| 100/100 [00:04<00:00, 21.62it/s]
# Epoch: 94/100, Discriminator loss: 0.6790707409381866, Generator loss:[3.9281609058380127, 0.7752209305763245, 0.029183097183704376, 0.023463068529963493]: 100%|██████████| 100/100 [00:04<00:00, 20.91it/s]
# Epoch: 95/100, Discriminator loss: 0.6748751997947693, Generator loss:[3.9171881675720215, 0.7795429229736328, 0.02905930206179619, 0.02317148447036743]: 100%|██████████| 100/100 [00:04<00:00, 20.67it/s]
# Epoch: 96/100, Discriminator loss: 0.6745128035545349, Generator loss:[3.934393882751465, 0.7736006379127502, 0.02929658629000187, 0.02311347797513008]: 100%|██████████| 100/100 [00:04<00:00, 20.59it/s]
# Epoch: 97/100, Discriminator loss: 0.6729763746261597, Generator loss:[3.9225783348083496, 0.7858275771141052, 0.029074465855956078, 0.02293042652308941]: 100%|██████████| 100/100 [00:04<00:00, 21.91it/s]
# Epoch: 98/100, Discriminator loss: 0.6738920211791992, Generator loss:[3.9247076511383057, 0.7736995220184326, 0.029223397374153137, 0.02286684513092041]: 100%|██████████| 100/100 [00:04<00:00, 22.21it/s]
# Epoch: 99/100, Discriminator loss: 0.6725845038890839, Generator loss:[3.8846235275268555, 0.7764158844947815, 0.028815247118473053, 0.022668257355690002]: 100%|██████████| 100/100 [00:04<00:00, 22.30it/s]
# Epoch: 100/100, Discriminator loss: 0.6727540194988251, Generator loss:[3.857250928878784, 0.7680369019508362, 0.028633685782551765, 0.022584550082683563]: 100%|██████████| 100/100 [00:04<00:00, 20.87it/s]

# %%
def sample_image(generator, imgs, masks, idx): 
    fig, ax = plt.subplots(1, 3, figsize=(15,5))

    ax[0].imshow(masks[idx]) 
    #ax[0].set_title()
    
    condition = masks[idx]/127.25-1
    generated = (generator.predict(condition[None])+1)*127.25 

    ax[1].imshow(generated[0].astype('uint8')) #показываем сгенерированное изображение
    ax[1].set_title('сгенерированное изображение')

    ax[2].imshow(imgs[idx]) #показываем исходное изображение
    ax[2].set_title('реальное изображение')

# %%
for i in [6,24,42,60]:
   sample_image(gen, imgs, masks, i)

# %%
A = np.matrix(np.random.randint(-5,5,(5,10)))
X = np.matrix(np.random.randint(5,10,(5,10)))
C = np.matrix(np.random.randint(10,15,(5,10)))
AX = np.dot(A, X.T)
Y = AX.dot(C)
Y.shape
# Out:
# (5, 10)

# %%
Y=A@X.T@C
Y.shape
# Out:
# (5, 10)
