# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtuomMerkulov/ArtuomMerkulov/blob/main/%22%D0%93%D0%B5%D0%BD%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D1%8F_%D1%81%D0%BA%D1%80%D0%B8%D0%BD%D1%88%D0%BE%D1%82%D0%BE%D0%B2_%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%BE%D0%B2_%D0%BC%D0%BE%D0%B1%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D0%B3%D1%80_3%22_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Генерация скриншотов экранов мобильных игр
# Для генерации использовал маску в качестве условия

# %%
# !pip install keras==2.0 -q 
# !pip install tensorflow==2.7.0 -q
# Out:
#      |████████████████████████████████| 191 kB 4.8 MB/s
#      |████████████████████████████████| 588.3 MB 20 kB/s
#      |████████████████████████████████| 439 kB 72.8 MB/s
#      |████████████████████████████████| 578.1 MB 8.1 kB/s
#      |████████████████████████████████| 578.1 MB 6.6 kB/s
#      |████████████████████████████████| 511.8 MB 27 kB/s
#      |████████████████████████████████| 511.7 MB 30 kB/s
#      |████████████████████████████████| 511.7 MB 209 bytes/s
#      |████████████████████████████████| 498.0 MB 13 kB/s
#      |████████████████████████████████| 5.8 MB 71.6 MB/s
#      |████████████████████████████████| 498.4 MB 26 kB/s
#      |████████████████████████████████| 498.0 MB 20 kB/s
#      |████████████████████████████████| 498.0 MB 30 kB/s
#      |████████████████████████████████| 497.6 MB 2.1 kB/s
#      |████████████████████████████████| 496.0 MB 12 kB/s
#      |████████████████████████████████| 463 kB 42.5 MB/s
#      |████████████████████████████████| 495.5 MB 18 kB/s
#      |████████████████████████████████| 495.5 MB 18 kB/s
#      |████████████████████████████████| 495.1 MB 8.5 kB/s
#      |████████████████████████████████| 489.6 MB 27 kB/s
#      |████████████████████████████████| 464.3 MB 36 kB/s
#      |████████████████████████████████| 462 kB 79.1 MB/s
#      |████████████████████████████████| 132 kB 59.0 MB/s
#      |████████████████████████████████| 14.9 MB 72.2 MB/s
#      |████████████████████████████████| 464.3 MB 688 bytes/s
#      |████████████████████████████████| 463.9 MB 22 kB/s
#      |████████████████████████████████| 458.4 MB 35 kB/s
#      |████████████████████████████████| 458.4 MB 19 kB/s
#      |████████████████████████████████| 458.4 MB 33 kB/s
#      |████████████████████████████████| 460.4 MB 39 kB/s
#      |████████████████████████████████| 4.0 MB 45.6 MB/s
#      |████████████████████████████████| 1.2 MB 75.8 MB/s
#      |████████████████████████████████| 462 kB 78.6 MB/s
#   Building wheel for keras (setup.py) ... done
#   Building wheel for termcolor (setup.py) ... done
#   Building wheel for wrapt (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# pydantic 1.10.2 requires typing-extensions>=4.1.0, but you have typing-extensions 3.7.4.3 which is incompatible.
# jaxlib 0.3.25+cuda11.cudnn805 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# jax 0.3.25 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# grpcio-status 1.48.2 requires grpcio>=1.48.2, but you have grpcio 1.34.1 which is incompatible.
# google-cloud-bigquery 3.3.6 requires grpcio<2.0dev,>=1.47.0, but you have grpcio 1.34.1 which is incompatible.
# cupy-cuda11x 11.0.0 requires numpy<1.26,>=1.20, but you have numpy 1.19.5 which is incompatible.
# cmdstanpy 1.0.8 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
#      |████████████████████████████████| 1.3 MB 5.1 MB/s

# %%
import scipy
import tensorflow as tf

from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate, LeakyReLU
from keras.layers import BatchNormalization, Add, add
from keras.layers import UpSampling2D, Conv2D
from keras.applications import vgg19
#from keras.utils import plot_model
from tensorflow.keras.utils import plot_model
#from tensorflow.keras.preprocessing.image import img_to_array, load_img
from keras.preprocessing.image import img_to_array, load_img
#from keras.models import Sequential, Model
from keras.models import Sequential, Model
#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
import os
import keras.backend as K
from tqdm import tqdm
from tensorflow.python.platform.tf_logging import set_verbosity, FATAL
set_verbosity(FATAL)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '0'

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unrar x '/content/drive/MyDrive/Numpy/Mоbile game loading screen.rar'
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/Numpy/Mоbile game loading screen.rar
#
# Creating    Mоbile game loading screen                                OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
img_shape = (128, 256, 3) #размер изображения
height = img_shape[0]
width = img_shape[1]

# %%
imgs = [] 
for image in sorted(os.listdir('/content/Mоbile game loading screen/')): #проходим по каждому файлу, получив список файлов в папке 
  print(image)
  imgs.append(img_to_array(load_img('/content/Mоbile game loading screen/'+image, target_size=(height,width)))) #загружаем файл, устанавливаем нужный размер и сохраняем в оперативную память, как массив numpy
imgs = np.stack(imgs).astype('uint8') #сохраняем итоговый массив изображений

masks = []
for image in sorted(os.listdir('/content/Mоbile game loading screen/')): #проходим по каждому файлу, получив список файлов в папке 
  masks.append(img_to_array(load_img('/content/Mоbile game loading screen/'+image, target_size=(height,width)))) #загружаем файл, устанавливаем нужный размер и сохраняем в оперативную память, как массив numpy
masks = np.stack(masks).astype('uint8') #сохраняем итоговый массив масок
# Out:
# 1010!.jpg
# 8 Ball pool.jpg
# Amaze.jpg
# Animal transform race.jpg
# Ball brick breaker.jpg
# Beat racing.jpg
# Billiards city.jpg
# Blob runner 3d.jpg
# Bob's world.jpg
# Body race.jpg
# Bottle flip 3d.jpg
# Brawl Stars.png
# Bridal Rush!.jpg
# Bridge race.jpg
# Call of duty mobile.jpg
# Cannon shot.jpg
# Carpet roller - dress and rugs.jpg
# Castle clash.png
# Cheerleader run 3d.jpg
# Clash of clans.jpg
# Color crush.jpg
# Colour adventure.jpg
# Comics Bob.jpg
# Cut and paint.jpg
# Dancing line origins.jpg
# Dancing road.jpg
# Delete puzzle.jpg
# Draw it story.jpg
# Draw joust.jpg
# Drop number.jpg
# Dunk shot.jpg
# Epic race 3d.jpg
# Fidget toys 3d.jpg
# Fruit Block - puzzle legend.jpg
# Fun race 3d.jpg
# Galaxy attack alien shooter.jpg
# GardenScapes.jpg
# Giant rush.jpg
# Going balls.jpg
# Golf blitz.jpg
# Heel master.jpg
# Helix stack jump.jpg
# Hide 'N seek.jpg
# Hit Master 3d.jpg
# Hit and knock down.jpg
# Home pin - how to loot.jpg
# Homescapes.jpeg
# Hop Ball 3.jpg
# IdleAnts.jpg
# Jelly shift.jpg
# Johnny Trigger.jpg
# Join and clash.jpg
# Join and strike.jpg
# Kick the Buddy.jpg
# Magic tiles 3.jpg
# Merge Block 3d.jpg
# Moto X3M.jpg
# Muscle rush.jpg
# Paper fold.jpg
# Paper's grade please!.jpg
# Pencil Rush 3d.jpg
# Perfect cream.jpg
# Pick me up 3d.jpg
# Plants vs zombies.jpg
# Player Unknow's Battlegrounds mobile.jpg
# Ramp car jumping.jpg
# Red Ball 4.jpg
# Rider.jpg
# Rocket punch.jpg
# Roof rails.jpg
# Rope slash.jpg
# Shooting ball.jpg
# Shortcut run.jpg
# Sky roller.jpg
# Sling drift.jpg
# Smash colors 3d.jpg
# Soap cutting.jpg
# Sort People Puzzle.jpg
# Spiral roll.jpg
# Stack colors.jpg
# Stack rider.jpg
# Stacky dash.jpg
# Standoff 2.jpg
# Stealth master.jpg
# Stickman Hook.jpg
# Sushi roll 3d.jpg
# Sword play.jpg
# Tangle Master 3d.jpg
# Tank stars.jpg
# Taxi run.jpg
# Tile Master 3d.jpg
# Tiles hop.jpg
# Zen idle - gravity meditation.jpg
# hill climb racing 2.jpg
# hill climb racing.jpg
# Долина сладостей.jpg
# Сальто к вершине.jpg
# Слияние мастера.jpg
# Слова из слова.jpg
# Туземцы.jpg

# %%
def build_generator():
    gf = 64 #минимальное число фильтров
    
    def conv2d(layer_input, filters, f_size=4, bn=True): #слой с понижением разрешения (encoder)
        
        d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input) #strides = 2 уменьшает разрешение в 2 раза при padding='same'
        d = LeakyReLU(alpha=0.2)(d)
        if bn:
            d = BatchNormalization(momentum=0.8)(d)
        return d

    def deconv2d(layer_input, skip_input, filters, f_size=4, dropout_rate=0): #слой с повышением разрешения (decoder) принимает на вход предыдущий слой и skip-слой от encoder'а
        u = UpSampling2D(size=2)(layer_input) #увеличивам разрешение в 2 раза
        u = Conv2D(filters, kernel_size=f_size, strides=1, padding='same', activation='relu')(u) #strides=1, padding='same',  поэтому разрешение сохраняется
        if dropout_rate:
            u = Dropout(dropout_rate)(u)
        u = BatchNormalization(momentum=0.8)(u)
        u = Concatenate()([u, skip_input]) #соединяем skip-слой и слой decoder'а
        return u

    d0 = Input(shape=img_shape, name="condition") #входное изображение (условие)

    # Часть encoder'a
    d1 = conv2d(d0, gf, bn=False)
    d2 = conv2d(d1, gf*2)
    d3 = conv2d(d2, gf*4) #чем меньше размер карт активаций
    d4 = conv2d(d3, gf*8) #тем больше должно быть фильтров в сверточном слое
    d5 = conv2d(d4, gf*8)
    d6 = conv2d(d5, gf*8)
    d7 = conv2d(d6, gf*8)

    # Часть decoder'a
    u1 = deconv2d(d7, d6, gf*8)
    u2 = deconv2d(u1, d5, gf*8) 
    u3 = deconv2d(u2, d4, gf*8) #чем больше размер карт активаций
    u4 = deconv2d(u3, d3, gf*4) #тем меньше должно быть фильтров в сверточном слое
    u5 = deconv2d(u4, d2, gf*2)
    u6 = deconv2d(u5, d1, gf)

    u7 = UpSampling2D(size=2)(u6)
    output_img = Conv2D(3, kernel_size=4, strides=1, padding='same', activation='tanh', name='G_output')(u7) 

    return Model(d0, output_img, name="G")

# %%
gen = build_generator() #создаем генератор
gen.summary()
# Out:
# Model: "G"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  condition (InputLayer)         [(None, 128, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 64, 128, 64)  3136        ['condition[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 64, 128, 64)  0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 64, 128)  131200      ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 32, 64, 128)  0           ['conv2d_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 64, 128)  512        ['leaky_re_lu_1[0][0]']
#  alization)
#
#  conv2d_2 (Conv2D)              (None, 16, 32, 256)  524544      ['batch_normalization[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 16, 32, 256)  0           ['conv2d_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 32, 256)  1024       ['leaky_re_lu_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 8, 16, 512)   2097664     ['batch_normalization_1[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 8, 16, 512)   0           ['conv2d_3[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 16, 512)  2048        ['leaky_re_lu_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 4, 8, 512)    4194816     ['batch_normalization_2[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 4, 8, 512)    0           ['conv2d_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 4, 8, 512)   2048        ['leaky_re_lu_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 2, 4, 512)    4194816     ['batch_normalization_3[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 2, 4, 512)    0           ['conv2d_5[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 2, 4, 512)   2048        ['leaky_re_lu_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 1, 2, 512)    4194816     ['batch_normalization_4[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 1, 2, 512)    0           ['conv2d_6[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 1, 2, 512)   2048        ['leaky_re_lu_6[0][0]']
#  rmalization)
#
#  up_sampling2d (UpSampling2D)   (None, 2, 4, 512)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 2, 4, 512)    4194816     ['up_sampling2d[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 2, 4, 512)   2048        ['conv2d_7[0][0]']
#  rmalization)
#
#  concatenate (Concatenate)      (None, 2, 4, 1024)   0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 4, 8, 1024)  0           ['concatenate[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 8, 512)    8389120     ['up_sampling2d_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 4, 8, 512)   2048        ['conv2d_8[0][0]']
#  rmalization)
#
#  concatenate_1 (Concatenate)    (None, 4, 8, 1024)   0           ['batch_normalization_7[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 8, 16, 1024)  0          ['concatenate_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 16, 512)   8389120     ['up_sampling2d_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 16, 512)  2048        ['conv2d_9[0][0]']
#  rmalization)
#
#  concatenate_2 (Concatenate)    (None, 8, 16, 1024)  0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 16, 32, 1024  0          ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 16, 32, 256)  4194560     ['up_sampling2d_3[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 32, 256)  1024       ['conv2d_10[0][0]']
#  rmalization)
#
#  concatenate_3 (Concatenate)    (None, 16, 32, 512)  0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 64, 512)  0          ['concatenate_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 64, 128)  1048704     ['up_sampling2d_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 64, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  concatenate_4 (Concatenate)    (None, 32, 64, 256)  0           ['batch_normalization_10[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 128, 256  0          ['concatenate_4[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 64, 128, 64)  262208      ['up_sampling2d_5[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 128, 64)  256        ['conv2d_12[0][0]']
#  ormalization)
#
#  concatenate_5 (Concatenate)    (None, 64, 128, 128  0           ['batch_normalization_11[0][0]',
#                                 )                                 'leaky_re_lu[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 128, 256, 12  0          ['concatenate_5[0][0]']
#                                 8)
#
#  G_output (Conv2D)              (None, 128, 256, 3)  6147        ['up_sampling2d_6[0][0]']
#
# ==================================================================================================
# Total params: 41,843,331
# Trainable params: 41,834,499
# Non-trainable params: 8,832
# __________________________________________________________________________________________________

# %%
def build_discriminator():
  
  df = 64 #минимальное число фильтров
  def d_layer(layer_input, filters, f_size=4, bn=True): #слой дискриминатора с понижением разрешения
      
      d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input) #размер карт активаций будет уменьшен в 2 раза, так как strides=2 при padding='same'
      d = LeakyReLU(alpha=0.2)(d)
      if bn:
          d = BatchNormalization(momentum=0.8)(d)
      return d

  image = Input(shape=img_shape, name="real_or_fake_A") #на вход дискриминатору подается либо реальное изображение, либо фейковое
  condition = Input(shape=img_shape, name="condition") #и дополнительно изображение-условие

  combined_imgs = Concatenate(axis=-1)([image, condition]) #объединяем оба входа в 1 слой

  d1 = d_layer(combined_imgs, df, bn=False)
  d2 = d_layer(d1, df*2)
  d3 = d_layer(d2, df*4) #уменьшаем размер карт активации, увеличивая их число
  d4 = d_layer(d3, df*8)

  validity = Conv2D(3, kernel_size=4, strides=1, padding='same', name='D_output', activation='sigmoid')(d4) #на выходе будет двумерный массив, каждый элемент которого определяет, подлинность части изображения (patch GAN)
                                                                                                            #0 отвечает за фейковые изображения, 1 за подлинные, поэтому используем sigmoid

  return Model([image, condition], validity, name='D')

# %%
dis = build_discriminator()
dis.summary()
# Out:
# Model: "D"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  real_or_fake_A (InputLayer)    [(None, 128, 256, 3  0           []
#                                 )]
#
#  condition (InputLayer)         [(None, 128, 256, 3  0           []
#                                 )]
#
#  concatenate_6 (Concatenate)    (None, 128, 256, 6)  0           ['real_or_fake_A[0][0]',
#                                                                   'condition[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 128, 64)  6208        ['concatenate_6[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 64, 128, 64)  0           ['conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 64, 128)  131200      ['leaky_re_lu_7[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 32, 64, 128)  0           ['conv2d_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 64, 128)  512        ['leaky_re_lu_8[0][0]']
#  ormalization)
#
#  conv2d_15 (Conv2D)             (None, 16, 32, 256)  524544      ['batch_normalization_12[0][0]']
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 16, 32, 256)  0           ['conv2d_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 32, 256)  1024       ['leaky_re_lu_9[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 8, 16, 512)   2097664     ['batch_normalization_13[0][0]']
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 8, 16, 512)   0           ['conv2d_16[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 8, 16, 512)  2048        ['leaky_re_lu_10[0][0]']
#  ormalization)
#
#  D_output (Conv2D)              (None, 8, 16, 3)     24579       ['batch_normalization_14[0][0]']
#
# ==================================================================================================
# Total params: 2,787,779
# Trainable params: 2,785,987
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
def build_vgg():
  vgg_in = Input(img_shape)
  vgg = vgg19.VGG19(include_top=False, input_shape=img_shape, input_tensor=vgg_in) #скачиваем архитектуру и веса 
  vgg_out = vgg.get_layer('block5_conv4').output #получаем последний сверточный слой
  vgg = Model(vgg_in, vgg_out, name='vgg')
  vgg.trainable = False #модель уже предобучена, поэтому ее необходимо заморозить

  return vgg

# %%
vgg = build_vgg()
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# Model: "vgg"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 128, 64)       0
#
#  block2_conv1 (Conv2D)       (None, 64, 128, 128)      73856
#
#  block2_conv2 (Conv2D)       (None, 64, 128, 128)      147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 16, 512)        0
#
#  block5_conv1 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv4 (Conv2D)       (None, 8, 16, 512)        2359808
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
def build_gan(generator, discriminator, vgg):
  discriminator.trainable = False #замораживаем дискриминатор

  condition = Input(img_shape, name='Condition') #вход изображения-условия
  fake_img = generator(condition) #изображение, полученное от генератора

  fake_features = vgg(fake_img) #карты активации, полученные от фейкового изображения

  fake_validity = discriminator([fake_img, condition]) #соединяем генератор и дискриминатор

  gan = Model(condition, [fake_validity, fake_img, fake_features]) #получаем gan с тремя выходами: первый отвечает за "правдоподобность", второй за изображение от генератора, третий за карты активации

  return gan

# %%
dis.output_shape[1:]
# Out:
# (8, 16, 3)

# %%
(np.ones((512, *dis.output_shape[1:]))).shape
# Out:
# (512, 8, 16, 3)

# %%
def train(generator, discriminator, gan, vgg, imgs, masks, epochs, batch_size):

  for epoch in range(epochs): 
    idx = np.random.choice(imgs.shape[0], imgs.shape[0], replace=False) #перемешиваем индексы, чтобы batch'и всегда были разными

    with tqdm(total=imgs.shape[0]) as pbar: #для отслеживания создаем progressbar
      for batch in range(imgs.shape[0]//batch_size):
        y_real = np.ones((batch_size, *discriminator.output_shape[1:])) - np.random.random_sample((batch_size, *discriminator.output_shape[1:]))*0.2
        y_fake = np.random.random_sample((batch_size, *discriminator.output_shape[1:]))*0.2

        idx_batch = idx[batch*batch_size:(batch+1)*batch_size] #получаем индексы для одного batch'а

        real_imgs = (imgs[idx_batch]/127.5)-1 #получаем истинные изображения и нормализуем их
        condition = (masks[idx_batch]/127.5)-1 #получаем маски и нормализуем их

        fake_imgs = generator.predict(condition) #генерируем изображения по маскам

        #тренируем дискриминатор       
        d_loss_real = discriminator.train_on_batch([real_imgs, condition], y_real)
        d_loss_fake = discriminator.train_on_batch([fake_imgs, condition], y_fake)
        d_loss_total = 0.5*np.add(d_loss_real, d_loss_fake)
   
        #тренируем генератор
        real_features = vgg.predict(real_imgs)
        y_real = np.ones((batch_size, *discriminator.output_shape[1:]))

        g_loss = gan.train_on_batch(condition, [y_real, real_imgs, real_features])
        pbar.update(batch_size) #обновляем progressbar
        pbar.set_description("Epoch: {}/{}, Discriminator loss: {}, Generator loss:{}".format(epoch+1, epochs, d_loss_total[0], g_loss))

# %%
gen = build_generator() #создаем генератор

dis = build_discriminator() #создаем дискриминатор
dis.compile(loss='binary_crossentropy', optimizer=Adam(lr=1e-4, beta_1=0.5), metrics=['accuracy'])

vgg = build_vgg() #создаем vgg модель

gan = build_gan(gen, dis, vgg) #создаем gan
gan.compile(loss=['binary_crossentropy', 'mse', 'mse'], loss_weights=[1,100,10], optimizer=Adam(lr=1e-4, beta_1=0.5)) #вклад разницы между пикселями в 10 раз больше, чем вклад от feature loss и в 100 раз больше, чем вклад от GAN
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
gen.summary()
# Out:
# Model: "G"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  condition (InputLayer)         [(None, 128, 256, 3  0           []
#                                 )]
#
#  conv2d_17 (Conv2D)             (None, 64, 128, 64)  3136        ['condition[0][0]']
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 64, 128, 64)  0           ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 64, 128)  131200      ['leaky_re_lu_11[0][0]']
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 32, 64, 128)  0           ['conv2d_18[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 64, 128)  512        ['leaky_re_lu_12[0][0]']
#  ormalization)
#
#  conv2d_19 (Conv2D)             (None, 16, 32, 256)  524544      ['batch_normalization_15[0][0]']
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 16, 32, 256)  0           ['conv2d_19[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 32, 256)  1024       ['leaky_re_lu_13[0][0]']
#  ormalization)
#
#  conv2d_20 (Conv2D)             (None, 8, 16, 512)   2097664     ['batch_normalization_16[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 8, 16, 512)   0           ['conv2d_20[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 8, 16, 512)  2048        ['leaky_re_lu_14[0][0]']
#  ormalization)
#
#  conv2d_21 (Conv2D)             (None, 4, 8, 512)    4194816     ['batch_normalization_17[0][0]']
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 4, 8, 512)    0           ['conv2d_21[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 4, 8, 512)   2048        ['leaky_re_lu_15[0][0]']
#  ormalization)
#
#  conv2d_22 (Conv2D)             (None, 2, 4, 512)    4194816     ['batch_normalization_18[0][0]']
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 2, 4, 512)    0           ['conv2d_22[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 2, 4, 512)   2048        ['leaky_re_lu_16[0][0]']
#  ormalization)
#
#  conv2d_23 (Conv2D)             (None, 1, 2, 512)    4194816     ['batch_normalization_19[0][0]']
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 1, 2, 512)    0           ['conv2d_23[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 1, 2, 512)   2048        ['leaky_re_lu_17[0][0]']
#  ormalization)
#
#  up_sampling2d_7 (UpSampling2D)  (None, 2, 4, 512)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 2, 4, 512)    4194816     ['up_sampling2d_7[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 2, 4, 512)   2048        ['conv2d_24[0][0]']
#  ormalization)
#
#  concatenate_7 (Concatenate)    (None, 2, 4, 1024)   0           ['batch_normalization_21[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 4, 8, 1024)  0           ['concatenate_7[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 4, 8, 512)    8389120     ['up_sampling2d_8[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 4, 8, 512)   2048        ['conv2d_25[0][0]']
#  ormalization)
#
#  concatenate_8 (Concatenate)    (None, 4, 8, 1024)   0           ['batch_normalization_22[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 8, 16, 1024)  0          ['concatenate_8[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 8, 16, 512)   8389120     ['up_sampling2d_9[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 16, 512)  2048        ['conv2d_26[0][0]']
#  ormalization)
#
#  concatenate_9 (Concatenate)    (None, 8, 16, 1024)  0           ['batch_normalization_23[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 16, 32, 1024  0          ['concatenate_9[0][0]']
#  )                              )
#
#  conv2d_27 (Conv2D)             (None, 16, 32, 256)  4194560     ['up_sampling2d_10[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 32, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  concatenate_10 (Concatenate)   (None, 16, 32, 512)  0           ['batch_normalization_24[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 32, 64, 512)  0          ['concatenate_10[0][0]']
#  )
#
#  conv2d_28 (Conv2D)             (None, 32, 64, 128)  1048704     ['up_sampling2d_11[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 64, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  concatenate_11 (Concatenate)   (None, 32, 64, 256)  0           ['batch_normalization_25[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  up_sampling2d_12 (UpSampling2D  (None, 64, 128, 256  0          ['concatenate_11[0][0]']
#  )                              )
#
#  conv2d_29 (Conv2D)             (None, 64, 128, 64)  262208      ['up_sampling2d_12[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 64, 128, 64)  256        ['conv2d_29[0][0]']
#  ormalization)
#
#  concatenate_12 (Concatenate)   (None, 64, 128, 128  0           ['batch_normalization_26[0][0]',
#                                 )                                 'leaky_re_lu_11[0][0]']
#
#  up_sampling2d_13 (UpSampling2D  (None, 128, 256, 12  0          ['concatenate_12[0][0]']
#  )                              8)
#
#  G_output (Conv2D)              (None, 128, 256, 3)  6147        ['up_sampling2d_13[0][0]']
#
# ==================================================================================================
# Total params: 41,843,331
# Trainable params: 41,834,499
# Non-trainable params: 8,832
# __________________________________________________________________________________________________

# %%
dis.summary()
# Out:
# Model: "D"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  real_or_fake_A (InputLayer)    [(None, 128, 256, 3  0           []
#                                 )]
#
#  condition (InputLayer)         [(None, 128, 256, 3  0           []
#                                 )]
#
#  concatenate_13 (Concatenate)   (None, 128, 256, 6)  0           ['real_or_fake_A[0][0]',
#                                                                   'condition[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 128, 64)  6208        ['concatenate_13[0][0]']
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 64, 128, 64)  0           ['conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 64, 128)  131200      ['leaky_re_lu_18[0][0]']
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 32, 64, 128)  0           ['conv2d_31[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 64, 128)  512        ['leaky_re_lu_19[0][0]']
#  ormalization)
#
#  conv2d_32 (Conv2D)             (None, 16, 32, 256)  524544      ['batch_normalization_27[0][0]']
#
#  leaky_re_lu_20 (LeakyReLU)     (None, 16, 32, 256)  0           ['conv2d_32[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 32, 256)  1024       ['leaky_re_lu_20[0][0]']
#  ormalization)
#
#  conv2d_33 (Conv2D)             (None, 8, 16, 512)   2097664     ['batch_normalization_28[0][0]']
#
#  leaky_re_lu_21 (LeakyReLU)     (None, 8, 16, 512)   0           ['conv2d_33[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 8, 16, 512)  2048        ['leaky_re_lu_21[0][0]']
#  ormalization)
#
#  D_output (Conv2D)              (None, 8, 16, 3)     24579       ['batch_normalization_29[0][0]']
#
# ==================================================================================================
# Total params: 2,787,779
# Trainable params: 0
# Non-trainable params: 2,787,779
# __________________________________________________________________________________________________

# %%
vgg.summary()
# Out:
# Model: "vgg"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 128, 64)       0
#
#  block2_conv1 (Conv2D)       (None, 64, 128, 128)      73856
#
#  block2_conv2 (Conv2D)       (None, 64, 128, 128)      147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 32, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 16, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 16, 512)        0
#
#  block5_conv1 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 16, 512)        2359808
#
#  block5_conv4 (Conv2D)       (None, 8, 16, 512)        2359808
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
train(gen, dis, gan, vgg, imgs, masks, 100, 100)
# Out:
# Epoch: 1/100, Discriminator loss: 0.8990171849727631, Generator loss:[61.6485595703125, 0.687086284160614, 0.600708544254303, 0.08906156569719315]: 100%|██████████| 100/100 [00:57<00:00,  1.74it/s]
# Epoch: 2/100, Discriminator loss: 1.051161527633667, Generator loss:[22.85083770751953, 0.6706881523132324, 0.21504417061805725, 0.06757321953773499]: 100%|██████████| 100/100 [00:04<00:00, 22.51it/s]
# Epoch: 3/100, Discriminator loss: 0.8871898353099823, Generator loss:[17.829877853393555, 0.6711288690567017, 0.16544581949710846, 0.06141668185591698]: 100%|██████████| 100/100 [00:04<00:00, 21.29it/s]
# Epoch: 4/100, Discriminator loss: 0.8037664294242859, Generator loss:[15.31433391571045, 0.6507170796394348, 0.14074835181236267, 0.05887822061777115]: 100%|██████████| 100/100 [00:04<00:00, 22.13it/s]
# Epoch: 5/100, Discriminator loss: 0.7574785947799683, Generator loss:[13.10000228881836, 0.6702634692192078, 0.11855799704790115, 0.057393886148929596]: 100%|██████████| 100/100 [00:04<00:00, 22.35it/s]
# Epoch: 6/100, Discriminator loss: 0.7313655018806458, Generator loss:[11.825867652893066, 0.6750883460044861, 0.105893075466156, 0.05614715442061424]: 100%|██████████| 100/100 [00:04<00:00, 21.97it/s]
# Epoch: 7/100, Discriminator loss: 0.7233700156211853, Generator loss:[10.79883098602295, 0.6764218211174011, 0.09568715840578079, 0.055369310081005096]: 100%|██████████| 100/100 [00:04<00:00, 20.94it/s]
# Epoch: 8/100, Discriminator loss: 0.7096518874168396, Generator loss:[10.050618171691895, 0.6980299353599548, 0.08809415996074677, 0.054317303001880646]: 100%|██████████| 100/100 [00:04<00:00, 22.38it/s]
# Epoch: 9/100, Discriminator loss: 0.7063816487789154, Generator loss:[9.471312522888184, 0.6909235119819641, 0.08249758929014206, 0.05306299030780792]: 100%|██████████| 100/100 [00:06<00:00, 14.40it/s]
# Epoch: 10/100, Discriminator loss: 0.7008466422557831, Generator loss:[9.016572952270508, 0.6962425112724304, 0.07799621671438217, 0.052070893347263336]: 100%|██████████| 100/100 [00:04<00:00, 21.25it/s]
# Epoch: 11/100, Discriminator loss: 0.6939274370670319, Generator loss:[8.696287155151367, 0.7036621570587158, 0.07482907921075821, 0.05097174271941185]: 100%|██████████| 100/100 [00:04<00:00, 20.82it/s]
# Epoch: 12/100, Discriminator loss: 0.698820024728775, Generator loss:[8.330177307128906, 0.700529932975769, 0.0712781473994255, 0.05018322914838791]: 100%|██████████| 100/100 [00:04<00:00, 21.87it/s]
# Epoch: 13/100, Discriminator loss: 0.6880731284618378, Generator loss:[8.038640022277832, 0.7047349810600281, 0.06844017654657364, 0.048988763242959976]: 100%|██████████| 100/100 [00:04<00:00, 20.49it/s]
# Epoch: 14/100, Discriminator loss: 0.6807489097118378, Generator loss:[7.7201337814331055, 0.6974092125892639, 0.0653906762599945, 0.04836570844054222]: 100%|██████████| 100/100 [00:04<00:00, 20.28it/s]
# Epoch: 15/100, Discriminator loss: 0.6773588955402374, Generator loss:[7.495866298675537, 0.6883939504623413, 0.06334072351455688, 0.04733999818563461]: 100%|██████████| 100/100 [00:04<00:00, 22.07it/s]
# Epoch: 16/100, Discriminator loss: 0.6789935529232025, Generator loss:[7.291351795196533, 0.6927863955497742, 0.06133173778653145, 0.04653916880488396]: 100%|██████████| 100/100 [00:04<00:00, 20.75it/s]
# Epoch: 17/100, Discriminator loss: 0.672374039888382, Generator loss:[7.1127519607543945, 0.6926552057266235, 0.059621162712574005, 0.04579808562994003]: 100%|██████████| 100/100 [00:04<00:00, 20.67it/s]
# Epoch: 18/100, Discriminator loss: 0.676531970500946, Generator loss:[6.879124641418457, 0.6998182535171509, 0.0573001429438591, 0.04492922127246857]: 100%|██████████| 100/100 [00:04<00:00, 21.95it/s]
# Epoch: 19/100, Discriminator loss: 0.6790174841880798, Generator loss:[6.703385829925537, 0.711591899394989, 0.055481962859630585, 0.04435979202389717]: 100%|██████████| 100/100 [00:04<00:00, 20.59it/s]
# Epoch: 20/100, Discriminator loss: 0.6815100908279419, Generator loss:[6.546942234039307, 0.709830641746521, 0.054013691842556, 0.043574247509241104]: 100%|██████████| 100/100 [00:04<00:00, 20.19it/s]
# Epoch: 21/100, Discriminator loss: 0.6857355535030365, Generator loss:[6.3961501121521, 0.7130957245826721, 0.05252509564161301, 0.043054450303316116]: 100%|██████████| 100/100 [00:04<00:00, 21.50it/s]
# Epoch: 22/100, Discriminator loss: 0.6900578439235687, Generator loss:[6.277845859527588, 0.7240973114967346, 0.051315728574991226, 0.042217567563056946]: 100%|██████████| 100/100 [00:04<00:00, 21.64it/s]
# Epoch: 23/100, Discriminator loss: 0.697139322757721, Generator loss:[6.161619663238525, 0.7325208187103271, 0.050109852105379105, 0.04181137681007385]: 100%|██████████| 100/100 [00:04<00:00, 20.40it/s]
# Epoch: 24/100, Discriminator loss: 0.6996689140796661, Generator loss:[6.064561367034912, 0.734070897102356, 0.049203645437955856, 0.04101262986660004]: 100%|██████████| 100/100 [00:04<00:00, 21.65it/s]
# Epoch: 25/100, Discriminator loss: 0.6999858915805817, Generator loss:[5.9443159103393555, 0.728201150894165, 0.04809477925300598, 0.0406637080013752]: 100%|██████████| 100/100 [00:04<00:00, 21.54it/s]
# Epoch: 26/100, Discriminator loss: 0.7012135684490204, Generator loss:[5.847635269165039, 0.7255637645721436, 0.047228842973709106, 0.039918698370456696]: 100%|██████████| 100/100 [00:04<00:00, 21.57it/s]
# Epoch: 27/100, Discriminator loss: 0.700535923242569, Generator loss:[5.745830059051514, 0.7321420311927795, 0.0461878664791584, 0.03949010744690895]: 100%|██████████| 100/100 [00:04<00:00, 20.26it/s]
# Epoch: 28/100, Discriminator loss: 0.7061659693717957, Generator loss:[5.642736911773682, 0.7236485481262207, 0.04529581964015961, 0.03895065560936928]: 100%|██████████| 100/100 [00:04<00:00, 21.43it/s]
# Epoch: 29/100, Discriminator loss: 0.7042611539363861, Generator loss:[5.580577850341797, 0.7333128452301025, 0.04463889077305794, 0.038337599486112595]: 100%|██████████| 100/100 [00:04<00:00, 21.69it/s]
# Epoch: 30/100, Discriminator loss: 0.7053126394748688, Generator loss:[5.500909805297852, 0.732852041721344, 0.04387877136468887, 0.03801807016134262]: 100%|██████████| 100/100 [00:04<00:00, 20.37it/s]
# Epoch: 31/100, Discriminator loss: 0.7060717642307281, Generator loss:[5.451031684875488, 0.7461698651313782, 0.043314360082149506, 0.037342485040426254]: 100%|██████████| 100/100 [00:04<00:00, 21.70it/s]
# Epoch: 32/100, Discriminator loss: 0.7080208361148834, Generator loss:[5.404428482055664, 0.7400468587875366, 0.04293067753314972, 0.03713137283921242]: 100%|██████████| 100/100 [00:04<00:00, 21.57it/s]
# Epoch: 33/100, Discriminator loss: 0.7071480453014374, Generator loss:[5.301445484161377, 0.739592969417572, 0.04197704792022705, 0.0364147424697876]: 100%|██████████| 100/100 [00:04<00:00, 21.76it/s]
# Epoch: 34/100, Discriminator loss: 0.7040196359157562, Generator loss:[5.195906162261963, 0.7353687286376953, 0.041001979261636734, 0.03603395074605942]: 100%|██████████| 100/100 [00:04<00:00, 20.13it/s]
# Epoch: 35/100, Discriminator loss: 0.7045821249485016, Generator loss:[5.1305832862854, 0.7347365021705627, 0.04041336476802826, 0.035451099276542664]: 100%|██████████| 100/100 [00:04<00:00, 20.16it/s]
# Epoch: 36/100, Discriminator loss: 0.7034140825271606, Generator loss:[5.067389488220215, 0.7352430820465088, 0.03981589153409004, 0.035055745393037796]: 100%|██████████| 100/100 [00:04<00:00, 20.15it/s]
# Epoch: 37/100, Discriminator loss: 0.7039170265197754, Generator loss:[5.010035037994385, 0.7311829924583435, 0.03932790830731392, 0.03460611030459404]: 100%|██████████| 100/100 [00:04<00:00, 21.02it/s]
# Epoch: 38/100, Discriminator loss: 0.7029045522212982, Generator loss:[4.955361843109131, 0.7360740900039673, 0.038781117647886276, 0.034117624163627625]: 100%|██████████| 100/100 [00:05<00:00, 19.72it/s]
# Epoch: 39/100, Discriminator loss: 0.7028222978115082, Generator loss:[4.890793800354004, 0.731279730796814, 0.0382174588739872, 0.033776797354221344]: 100%|██████████| 100/100 [00:04<00:00, 21.88it/s]
# Epoch: 40/100, Discriminator loss: 0.7026875913143158, Generator loss:[4.833294868469238, 0.7345868945121765, 0.03766670450568199, 0.03320373594760895]: 100%|██████████| 100/100 [00:04<00:00, 21.45it/s]
# Epoch: 41/100, Discriminator loss: 0.7016973793506622, Generator loss:[4.7835373878479, 0.7316978573799133, 0.037233222275972366, 0.03285174444317818]: 100%|██████████| 100/100 [00:04<00:00, 20.18it/s]
# Epoch: 42/100, Discriminator loss: 0.702393114566803, Generator loss:[4.77536153793335, 0.7312086224555969, 0.0371994823217392, 0.03242044895887375]: 100%|██████████| 100/100 [00:04<00:00, 20.08it/s]
# Epoch: 43/100, Discriminator loss: 0.7008563876152039, Generator loss:[4.731594085693359, 0.7312883138656616, 0.036788374185562134, 0.03214685991406441]: 100%|██████████| 100/100 [00:04<00:00, 20.18it/s]
# Epoch: 44/100, Discriminator loss: 0.7018240392208099, Generator loss:[4.693943500518799, 0.7293278574943542, 0.03647308796644211, 0.03173070773482323]: 100%|██████████| 100/100 [00:04<00:00, 20.39it/s]
# Epoch: 45/100, Discriminator loss: 0.6998098194599152, Generator loss:[4.61347770690918, 0.7326610088348389, 0.03567536920309067, 0.03132800757884979]: 100%|██████████| 100/100 [00:04<00:00, 21.61it/s]
# Epoch: 46/100, Discriminator loss: 0.7009861767292023, Generator loss:[4.566836357116699, 0.7272393703460693, 0.035299040377140045, 0.03096929006278515]: 100%|██████████| 100/100 [00:04<00:00, 21.55it/s]
# Epoch: 47/100, Discriminator loss: 0.6998384296894073, Generator loss:[4.5543928146362305, 0.7336905598640442, 0.035156283527612686, 0.030507363379001617]: 100%|██████████| 100/100 [00:04<00:00, 21.69it/s]
# Epoch: 48/100, Discriminator loss: 0.7003639936447144, Generator loss:[4.496790409088135, 0.7274070978164673, 0.034666478633880615, 0.03027353063225746]: 100%|██████████| 100/100 [00:04<00:00, 21.40it/s]
# Epoch: 49/100, Discriminator loss: 0.699289858341217, Generator loss:[4.4695210456848145, 0.7319182753562927, 0.034403491765260696, 0.02972535602748394]: 100%|██████████| 100/100 [00:04<00:00, 20.32it/s]
# Epoch: 50/100, Discriminator loss: 0.6991032063961029, Generator loss:[4.445918560028076, 0.7285630106925964, 0.034215256571769714, 0.02958296239376068]: 100%|██████████| 100/100 [00:04<00:00, 21.36it/s]
# Epoch: 51/100, Discriminator loss: 0.6987403929233551, Generator loss:[4.481507301330566, 0.7304994463920593, 0.03458685055375099, 0.029232269152998924]: 100%|██████████| 100/100 [00:04<00:00, 21.58it/s]
# Epoch: 52/100, Discriminator loss: 0.6977536380290985, Generator loss:[4.445313453674316, 0.7296093106269836, 0.0342344269156456, 0.029226182028651237]: 100%|██████████| 100/100 [00:04<00:00, 21.68it/s]
# Epoch: 53/100, Discriminator loss: 0.6993750929832458, Generator loss:[4.421260356903076, 0.7281163930892944, 0.034053653478622437, 0.028777845203876495]: 100%|██████████| 100/100 [00:04<00:00, 21.56it/s]
# Epoch: 54/100, Discriminator loss: 0.6962509453296661, Generator loss:[4.475185871124268, 0.7310472130775452, 0.03456377983093262, 0.028776083141565323]: 100%|██████████| 100/100 [00:04<00:00, 20.34it/s]
# Epoch: 55/100, Discriminator loss: 0.6983365416526794, Generator loss:[4.3476996421813965, 0.7297507524490356, 0.03333347663283348, 0.028460126370191574]: 100%|██████████| 100/100 [00:04<00:00, 20.46it/s]
# Epoch: 56/100, Discriminator loss: 0.698315441608429, Generator loss:[4.268036365509033, 0.7268425226211548, 0.032617636024951935, 0.027943052351474762]: 100%|██████████| 100/100 [00:04<00:00, 21.64it/s]
# Epoch: 57/100, Discriminator loss: 0.697373628616333, Generator loss:[4.193655490875244, 0.7300105094909668, 0.031910404562950134, 0.02726045995950699]: 100%|██████████| 100/100 [00:07<00:00, 13.21it/s]
# Epoch: 58/100, Discriminator loss: 0.6984262764453888, Generator loss:[4.133259296417236, 0.7248249650001526, 0.031386956572532654, 0.02697388082742691]: 100%|██████████| 100/100 [00:04<00:00, 21.50it/s]
# Epoch: 59/100, Discriminator loss: 0.6971742212772369, Generator loss:[4.0794830322265625, 0.7256388068199158, 0.030902685597538948, 0.026357553899288177]: 100%|██████████| 100/100 [00:04<00:00, 21.67it/s]
# Epoch: 60/100, Discriminator loss: 0.6970066428184509, Generator loss:[4.049405097961426, 0.7249358892440796, 0.030645564198493958, 0.025991320610046387]: 100%|██████████| 100/100 [00:04<00:00, 21.52it/s]
# Epoch: 61/100, Discriminator loss: 0.6964247226715088, Generator loss:[4.020333290100098, 0.726215660572052, 0.030375801026821136, 0.025653785094618797]: 100%|██████████| 100/100 [00:04<00:00, 21.80it/s]
# Epoch: 62/100, Discriminator loss: 0.6964618563652039, Generator loss:[3.994568109512329, 0.7270429730415344, 0.030141590163111687, 0.025336630642414093]: 100%|██████████| 100/100 [00:04<00:00, 20.39it/s]
# Epoch: 63/100, Discriminator loss: 0.6963947415351868, Generator loss:[3.9686498641967773, 0.7295395135879517, 0.029895048588514328, 0.024960575625300407]: 100%|██████████| 100/100 [00:04<00:00, 21.73it/s]
# Epoch: 64/100, Discriminator loss: 0.6977081000804901, Generator loss:[3.9522244930267334, 0.728851318359375, 0.029759204015135765, 0.024745283648371696]: 100%|██████████| 100/100 [00:04<00:00, 21.09it/s]
# Epoch: 65/100, Discriminator loss: 0.6991841197013855, Generator loss:[3.9514522552490234, 0.7345300316810608, 0.029723016545176506, 0.024462055414915085]: 100%|██████████| 100/100 [00:04<00:00, 20.14it/s]
# Epoch: 66/100, Discriminator loss: 0.7014803886413574, Generator loss:[3.966223955154419, 0.7286521196365356, 0.02993394434452057, 0.02441776730120182]: 100%|██████████| 100/100 [00:04<00:00, 21.60it/s]
# Epoch: 67/100, Discriminator loss: 0.6989421248435974, Generator loss:[4.001562118530273, 0.7311204671859741, 0.030276304110884666, 0.024281125515699387]: 100%|██████████| 100/100 [00:04<00:00, 20.35it/s]
# Epoch: 68/100, Discriminator loss: 0.697795569896698, Generator loss:[4.004412651062012, 0.7266474962234497, 0.030344288796186447, 0.024333596229553223]: 100%|██████████| 100/100 [00:04<00:00, 20.39it/s]
# Epoch: 69/100, Discriminator loss: 0.6972318291664124, Generator loss:[3.9805963039398193, 0.7323333621025085, 0.030058227479457855, 0.0242440328001976]: 100%|██████████| 100/100 [00:04<00:00, 20.17it/s]
# Epoch: 70/100, Discriminator loss: 0.7012601792812347, Generator loss:[3.9689230918884277, 0.7299768924713135, 0.02996758371591568, 0.024218782782554626]: 100%|██████████| 100/100 [00:04<00:00, 20.33it/s]
# Epoch: 71/100, Discriminator loss: 0.7005199491977692, Generator loss:[3.9358179569244385, 0.7240356206893921, 0.0297544002532959, 0.023634184151887894]: 100%|██████████| 100/100 [00:04<00:00, 20.17it/s]
# Epoch: 72/100, Discriminator loss: 0.6948851644992828, Generator loss:[3.8129239082336426, 0.7275075316429138, 0.02852701023221016, 0.02327154576778412]: 100%|██████████| 100/100 [00:04<00:00, 20.36it/s]
# Epoch: 73/100, Discriminator loss: 0.694817841053009, Generator loss:[3.773211717605591, 0.7285035848617554, 0.02815079689025879, 0.02296283096075058]: 100%|██████████| 100/100 [00:04<00:00, 21.69it/s]
# Epoch: 74/100, Discriminator loss: 0.6944654881954193, Generator loss:[3.739548921585083, 0.7252677083015442, 0.027886543422937393, 0.022562693804502487]: 100%|██████████| 100/100 [00:04<00:00, 21.61it/s]
# Epoch: 75/100, Discriminator loss: 0.6942403316497803, Generator loss:[3.716247797012329, 0.7273587584495544, 0.027659112587571144, 0.02229776605963707]: 100%|██████████| 100/100 [00:04<00:00, 20.19it/s]
# Epoch: 76/100, Discriminator loss: 0.6948889195919037, Generator loss:[3.681854486465454, 0.7244118452072144, 0.027381276711821556, 0.021931486204266548]: 100%|██████████| 100/100 [00:04<00:00, 20.30it/s]
# Epoch: 77/100, Discriminator loss: 0.6942742764949799, Generator loss:[3.6547088623046875, 0.7253045439720154, 0.02712499164044857, 0.021690502762794495]: 100%|██████████| 100/100 [00:04<00:00, 21.70it/s]
# Epoch: 78/100, Discriminator loss: 0.6947862207889557, Generator loss:[3.634127616882324, 0.7257359027862549, 0.02694857306778431, 0.021353421732783318]: 100%|██████████| 100/100 [00:04<00:00, 21.37it/s]
# Epoch: 79/100, Discriminator loss: 0.6942441761493683, Generator loss:[3.6314797401428223, 0.7258613705635071, 0.02693261206150055, 0.021235719323158264]: 100%|██████████| 100/100 [00:04<00:00, 21.68it/s]
# Epoch: 80/100, Discriminator loss: 0.694176197052002, Generator loss:[3.6428356170654297, 0.7272114753723145, 0.02705470845103264, 0.021015331149101257]: 100%|██████████| 100/100 [00:04<00:00, 20.07it/s]
# Epoch: 81/100, Discriminator loss: 0.6939928531646729, Generator loss:[3.6629478931427, 0.7234593033790588, 0.027279281988739967, 0.021156053990125656]: 100%|██████████| 100/100 [00:04<00:00, 21.71it/s]
# Epoch: 82/100, Discriminator loss: 0.6941289603710175, Generator loss:[3.650357723236084, 0.7295619249343872, 0.02712160162627697, 0.02086358331143856]: 100%|██████████| 100/100 [00:04<00:00, 20.16it/s]
# Epoch: 83/100, Discriminator loss: 0.6938431560993195, Generator loss:[3.591343641281128, 0.7240244150161743, 0.026608314365148544, 0.020648786798119545]: 100%|██████████| 100/100 [00:04<00:00, 21.73it/s]
# Epoch: 84/100, Discriminator loss: 0.6940881609916687, Generator loss:[3.553290367126465, 0.7280181050300598, 0.02621939219534397, 0.020333318039774895]: 100%|██████████| 100/100 [00:04<00:00, 21.37it/s]
# Epoch: 85/100, Discriminator loss: 0.6942124962806702, Generator loss:[3.5504627227783203, 0.7266426086425781, 0.026229465380311012, 0.02008737064898014]: 100%|██████████| 100/100 [00:04<00:00, 21.51it/s]
# Epoch: 86/100, Discriminator loss: 0.693875253200531, Generator loss:[3.5703117847442627, 0.7242605686187744, 0.02644279971718788, 0.02017715945839882]: 100%|██████████| 100/100 [00:04<00:00, 21.37it/s]
# Epoch: 87/100, Discriminator loss: 0.6934876441955566, Generator loss:[3.5075342655181885, 0.7255136966705322, 0.025849828496575356, 0.019703760743141174]: 100%|██████████| 100/100 [00:04<00:00, 21.52it/s]
# Epoch: 88/100, Discriminator loss: 0.693350076675415, Generator loss:[3.4659125804901123, 0.7232011556625366, 0.025479409843683243, 0.019477063789963722]: 100%|██████████| 100/100 [00:04<00:00, 20.38it/s]
# Epoch: 89/100, Discriminator loss: 0.6934499442577362, Generator loss:[3.468106269836426, 0.7276099920272827, 0.02546749822795391, 0.01937464438378811]: 100%|██████████| 100/100 [00:06<00:00, 14.38it/s]
# Epoch: 90/100, Discriminator loss: 0.6934635043144226, Generator loss:[3.4672415256500244, 0.7230952978134155, 0.02552122436463833, 0.019202394410967827]: 100%|██████████| 100/100 [00:04<00:00, 20.07it/s]
# Epoch: 91/100, Discriminator loss: 0.6937046051025391, Generator loss:[3.5032546520233154, 0.7310895323753357, 0.025787997990846634, 0.019336536526679993]: 100%|██████████| 100/100 [00:05<00:00, 19.29it/s]
# Epoch: 92/100, Discriminator loss: 0.6943336725234985, Generator loss:[3.446965217590332, 0.7258842587471008, 0.025308556854724884, 0.019022565335035324]: 100%|██████████| 100/100 [00:04<00:00, 21.57it/s]
# Epoch: 93/100, Discriminator loss: 0.695495992898941, Generator loss:[3.4041616916656494, 0.7308441996574402, 0.02485286071896553, 0.018803143873810768]: 100%|██████████| 100/100 [00:04<00:00, 21.74it/s]
# Epoch: 94/100, Discriminator loss: 0.6949754357337952, Generator loss:[3.364734411239624, 0.7282649874687195, 0.024516083300113678, 0.018486104905605316]: 100%|██████████| 100/100 [00:04<00:00, 21.36it/s]
# Epoch: 95/100, Discriminator loss: 0.6942748427391052, Generator loss:[3.3540375232696533, 0.7243762016296387, 0.024468431249260902, 0.018281813710927963]: 100%|██████████| 100/100 [00:04<00:00, 20.28it/s]
# Epoch: 96/100, Discriminator loss: 0.6928397119045258, Generator loss:[3.372872829437256, 0.7287518382072449, 0.02461002580821514, 0.018311835825443268]: 100%|██████████| 100/100 [00:04<00:00, 21.44it/s]
# Epoch: 97/100, Discriminator loss: 0.6949256360530853, Generator loss:[3.403273344039917, 0.7273122668266296, 0.02493070438504219, 0.018289055675268173]: 100%|██████████| 100/100 [00:04<00:00, 21.26it/s]
# Epoch: 98/100, Discriminator loss: 0.6950216591358185, Generator loss:[3.3727993965148926, 0.7283990979194641, 0.0246296189725399, 0.01814384199678898]: 100%|██████████| 100/100 [00:04<00:00, 21.66it/s]
# Epoch: 99/100, Discriminator loss: 0.6956199109554291, Generator loss:[3.364661455154419, 0.7270848155021667, 0.024568134918808937, 0.01807630993425846]: 100%|██████████| 100/100 [00:04<00:00, 20.13it/s]
# Epoch: 100/100, Discriminator loss: 0.6942718029022217, Generator loss:[3.309412956237793, 0.7300475835800171, 0.024026913568377495, 0.017667386680841446]: 100%|██████████| 100/100 [00:04<00:00, 21.76it/s]

# %%
def sample_image(generator, imgs, masks, idx): 
    fig, ax = plt.subplots(1, 3, figsize=(15,5))

    ax[0].imshow(masks[idx]) 
    #ax[0].set_title()
    
    condition = masks[idx]/127.5-1
    generated = (generator.predict(condition[None])+1)*127.5 

    ax[1].imshow(generated[0].astype('uint8')) #показываем сгенерированное изображение
    ax[1].set_title('сгенерированное изображение')

    ax[2].imshow(imgs[idx]) #показываем исходное изображение
    ax[2].set_title('реальное изображение')

# %%
for i in [0,1,11,22,33,44,55,66,77,88,99]:
   sample_image(gen, imgs, masks, i)

# %%
A = np.matrix(np.random.randint(-5,5,(5,10)))
X = np.matrix(np.random.randint(5,10,(5,10)))
C = np.matrix(np.random.randint(10,15,(5,10)))
AX = np.dot(A, X.T)
Y = AX.dot(C)
Y.shape
# Out:
# (5, 10)
