# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtuomMerkulov/ArtuomMerkulov/blob/main/%D0%9A%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D1%8F%20%D0%B8%20%D1%80%D0%B0%D1%81%D0%BF%D0%BE%D0%B7%D0%BD%D0%B0%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B0%D1%80%D0%BE%D0%BA%20%D0%B0%D0%B2%D1%82%D0%BE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image classification

# %%
# !pip install keras==2.0 -q 
# !pip install tensorflow==2.7.0 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.9/191.9 KB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.1/578.1 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.1/578.1 MB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 KB 40.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.4/498.4 MB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 KB 34.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.0/496.0 MB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.5/495.5 MB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.5/495.5 MB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.1/495.1 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.6/489.6 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.3/464.3 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.3/464.3 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.9/463.9 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.4/458.4 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.4/458.4 MB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 17.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.9/462.9 KB 40.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.4/458.4 MB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.4/460.4 MB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.4/462.4 KB 43.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 80.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 85.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for keras (setup.py) ... done
#   Building wheel for termcolor (setup.py) ... done
#   Building wheel for wrapt (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# xarray-einstats 0.4.0 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# pydantic 1.10.4 requires typing-extensions>=4.2.0, but you have typing-extensions 3.7.4.3 which is incompatible.
# jaxlib 0.3.25+cuda11.cudnn805 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# jax 0.3.25 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# grpcio-status 1.48.2 requires grpcio>=1.48.2, but you have grpcio 1.34.1 which is incompatible.
# google-cloud-bigquery 3.4.1 requires grpcio<2.0dev,>=1.47.0, but you have grpcio 1.34.1 which is incompatible.
# cupy-cuda11x 11.0.0 requires numpy<1.26,>=1.20, but you have numpy 1.19.5 which is incompatible.
# cmdstanpy 1.0.8 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.1/463.1 KB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.7 MB/s eta 0:00:00

# %% [markdown]
# ## Импортируем необходимые библиотеки

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator # работа с изображениями
from tensorflow.keras.optimizers import Adam, Adadelta # оптимизаторы
from tensorflow.keras import utils #Используем дял to_categoricall
from tensorflow.keras.preprocessing import image #Для отрисовки изображений
from google.colab import files #Для загрузки своей картинки
import numpy as np #Библиотека работы с массивами
import matplotlib.pyplot as plt #Для отрисовки графиков
from PIL import Image #Для отрисовки изображений
import random #Для генерации случайных чисел 
import math # Для округления
import os 
from google.colab import drive
import gdown
import tensorflow as tf
import PIL
from tensorflow import keras
from tensorflow.keras import layers

# %matplotlib inline

# %% [markdown]
# ## Download and explore the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pathlib

data_dir = '/content/drive/MyDrive/Numpy/car_classification'
data_dir = pathlib.Path(data_dir)

# %% [markdown]
# After downloading, you should now have a copy of the dataset available. There are 1050 total images:

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print(image_count)
# Out:
# 1050

# %%
roses = list(data_dir.glob('AUDI/*'))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=115x92 at 0x7F24246A8CA0>

# %%
PIL.Image.open(str(roses[10]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=286x149 at 0x7F248C1543D0>

# %%
tulips = list(data_dir.glob('BMW/*'))
PIL.Image.open(str(tulips[20]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=363x307 at 0x7F242463CB50>

# %%
PIL.Image.open(str(tulips[11]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=229x162 at 0x7F248C137D60>

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 75
img_height = 50
img_width = 100

# %% [markdown]
# При разработке модели рекомендуется использовать разделение проверки. Давайте используем 75% изображений для обучения и 25% для проверки.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.25,
  subset="training",
  seed=125,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1050 files belonging to 36 classes.
# Using 788 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.25,
  subset="validation",
  seed=125,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1050 files belonging to 36 classes.
# Using 262 files for validation.

# %% [markdown]
# Вы можете найти имена классов в атрибуте class_names в этих наборах данных.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['AUDI', 'BMW', 'Chery', 'Chevrolet', 'Chryslerр', 'Citroën', 'Daewoo', 'Dodge', 'Ford', 'HONDA', 'HYUNDAI', 'Infiniti', 'JEEP', 'Jaguar', 'KIA', 'LADA', 'Land Rover Range Rover', 'Lexus', 'Mazda', 'Mercedes', 'Mitsubishi', 'Nissan', 'Opel', 'Porsche', 'Renault', 'SUBARU', 'Skoda', 'Ssang Yong', 'Suzuki', 'Toyota', 'Volkswagen', 'Volvo', 'АЗЛК', 'АКУРА', 'ГАЗ', 'ЗАЗ   ZAZ']

# %% [markdown]
# ## Visualize the data

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 20))
for images, labels in train_ds.take(1):
  for i in range(8):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (75, 50, 100, 3)
# (75,)

# %% [markdown]
# ## Configure the dataset for performance

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standardize the data

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# ## A basic Keras model
#
# ### Create the model

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Model summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 50, 100, 3)        0
#
#  conv2d (Conv2D)             (None, 50, 100, 32)       896
#
#  max_pooling2d (MaxPooling2D  (None, 25, 50, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 25, 50, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 25, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 25, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 12, 128)       0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 256)               2359552
#
#  dense_1 (Dense)             (None, 36)                9252
#
# =================================================================
# Total params: 2,462,052
# Trainable params: 2,462,052
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 65s 6s/step - loss: 3.2947 - accuracy: 0.0812 - val_loss: 3.1494 - val_accuracy: 0.0992
# Epoch 2/100
# 11/11 [==============================] - 0s 22ms/step - loss: 3.1383 - accuracy: 0.1117 - val_loss: 3.1405 - val_accuracy: 0.1527
# Epoch 3/100
# 11/11 [==============================] - 0s 17ms/step - loss: 3.0916 - accuracy: 0.1206 - val_loss: 3.1759 - val_accuracy: 0.0992
# Epoch 4/100
# 11/11 [==============================] - 0s 16ms/step - loss: 3.0387 - accuracy: 0.1307 - val_loss: 3.1106 - val_accuracy: 0.1565
# Epoch 5/100
# 11/11 [==============================] - 0s 17ms/step - loss: 2.9925 - accuracy: 0.1193 - val_loss: 3.0757 - val_accuracy: 0.1489
# Epoch 6/100
# 11/11 [==============================] - 0s 17ms/step - loss: 2.8692 - accuracy: 0.1815 - val_loss: 3.0858 - val_accuracy: 0.1450
# Epoch 7/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.7728 - accuracy: 0.2132 - val_loss: 3.0672 - val_accuracy: 0.1450
# Epoch 8/100
# 11/11 [==============================] - 0s 18ms/step - loss: 2.6565 - accuracy: 0.2424 - val_loss: 3.1998 - val_accuracy: 0.1336
# Epoch 9/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.5260 - accuracy: 0.2779 - val_loss: 3.2419 - val_accuracy: 0.1718
# Epoch 10/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.2478 - accuracy: 0.3693 - val_loss: 3.3748 - val_accuracy: 0.1298
# Epoch 11/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.9641 - accuracy: 0.4201 - val_loss: 3.4661 - val_accuracy: 0.1489
# Epoch 12/100
# 11/11 [==============================] - 0s 16ms/step - loss: 1.7172 - accuracy: 0.5152 - val_loss: 3.8128 - val_accuracy: 0.1756
# Epoch 13/100
# 11/11 [==============================] - 0s 16ms/step - loss: 1.3692 - accuracy: 0.6117 - val_loss: 3.8246 - val_accuracy: 0.1832
# Epoch 14/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.9840 - accuracy: 0.7094 - val_loss: 4.1915 - val_accuracy: 0.1870
# Epoch 15/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.6521 - accuracy: 0.8350 - val_loss: 4.9590 - val_accuracy: 0.1679
# Epoch 16/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.4000 - accuracy: 0.8909 - val_loss: 5.7043 - val_accuracy: 0.1489
# Epoch 17/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.2783 - accuracy: 0.9327 - val_loss: 5.6042 - val_accuracy: 0.1527
# Epoch 18/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.1775 - accuracy: 0.9556 - val_loss: 6.5457 - val_accuracy: 0.1641
# Epoch 19/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0972 - accuracy: 0.9911 - val_loss: 6.4466 - val_accuracy: 0.1870
# Epoch 20/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0455 - accuracy: 0.9962 - val_loss: 7.1402 - val_accuracy: 0.1641
# Epoch 21/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0236 - accuracy: 0.9987 - val_loss: 7.3798 - val_accuracy: 0.1756
# Epoch 22/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0149 - accuracy: 0.9987 - val_loss: 7.4695 - val_accuracy: 0.1794
# Epoch 23/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 7.5507 - val_accuracy: 0.1679
# Epoch 24/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 7.8489 - val_accuracy: 0.1679
# Epoch 25/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 7.9753 - val_accuracy: 0.1603
# Epoch 26/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 8.1063 - val_accuracy: 0.1756
# Epoch 27/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss:
100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.5364e-04 - accuracy: 1.0000 - val_loss: 10.1346 - val_accuracy: 0.1718
# Epoch 83/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.4810e-04 - accuracy: 1.0000 - val_loss: 10.1576 - val_accuracy: 0.1679
# Epoch 84/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.4208e-04 - accuracy: 1.0000 - val_loss: 10.1734 - val_accuracy: 0.1756
# Epoch 85/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.3677e-04 - accuracy: 1.0000 - val_loss: 10.1915 - val_accuracy: 0.1718
# Epoch 86/100
# 11/11 [==============================] - 0s 17ms/step - loss: 2.3139e-04 - accuracy: 1.0000 - val_loss: 10.2125 - val_accuracy: 0.1756
# Epoch 87/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.2687e-04 - accuracy: 1.0000 - val_loss: 10.2324 - val_accuracy: 0.1718
# Epoch 88/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.2172e-04 - accuracy: 1.0000 - val_loss: 10.2468 - val_accuracy: 0.1679
# Epoch 89/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.1705e-04 - accuracy: 1.0000 - val_loss: 10.2684 - val_accuracy: 0.1718
# Epoch 90/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.1281e-04 - accuracy: 1.0000 - val_loss: 10.2839 - val_accuracy: 0.1756
# Epoch 91/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.0766e-04 - accuracy: 1.0000 - val_loss: 10.3058 - val_accuracy: 0.1718
# Epoch 92/100
# 11/11 [==============================] - 0s 16ms/step - loss: 2.0392e-04 - accuracy: 1.0000 - val_loss: 10.3230 - val_accuracy: 0.1679
# Epoch 93/100
# 11/11 [==============================] - 0s 16ms/step - loss: 1.9985e-04 - accuracy: 1.0000 - val_loss: 10.3321 - val_accuracy: 0.1679
# Epoch 94/100
# 11/11 [==============================] - 0s 17ms/step - loss: 1.9654e-04 - accuracy: 1.0000 - val_loss: 10.3543 - val_accuracy: 0.1756
# Epoch 95/100
# 11/11 [==============================] - 0s 17ms/step - loss: 1.9194e-04 - accuracy: 1.0000 - val_loss: 10.3726 - val_accuracy: 0.1756
# Epoch 96/100
# 11/11 [==============================] - 0s 16ms/step - loss: 1.8761e-04 - accuracy: 1.0000 - val_loss: 10.3856 - val_accuracy: 0.1679
# Epoch 97/100
# 11/11 [==============================] - 0s 16ms/step - loss: 1.8439e-04 - accuracy: 1.0000 - val_loss: 10.4016 - val_accuracy: 0.1679
# Epoch 98/100
# 11/11 [==============================] - 0s 16ms/step - loss: 1.8091e-04 - accuracy: 1.0000 - val_loss: 10.4180 - val_accuracy: 0.1679
# Epoch 99/100
# 11/11 [==============================] - 0s 17ms/step - loss: 1.7742e-04 - accuracy: 1.0000 - val_loss: 10.4399 - val_accuracy: 0.1756
# Epoch 100/100
# 11/11 [==============================] - 0s 16ms/step - loss: 1.7392e-04 - accuracy: 1.0000 - val_loss: 10.4548 - val_accuracy: 0.1718

# %% [markdown]
# ## Visualize training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Data augmentation

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ## Dropout

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %% [markdown]
# ## Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 50, 100, 3)        0
#
#  rescaling_2 (Rescaling)     (None, 50, 100, 3)        0
#
#  conv2d_3 (Conv2D)           (None, 50, 100, 32)       896
#
#  max_pooling2d_3 (MaxPooling  (None, 25, 50, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 25, 50, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 25, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 25, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 12, 128)       0
#  2D)
#
#  dropout (Dropout)           (None, 6, 12, 128)        0
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 256)               2359552
#
#  outputs (Dense)             (None, 36)                9252
#
# =================================================================
# Total params: 2,462,052
# Trainable params: 2,462,052
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 56
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/56
# 11/11 [==============================] - 0s 40ms/step - loss: 2.0861 - accuracy: 0.3541 - val_loss: 4.3071 - val_accuracy: 0.1374
# Epoch 2/56
# 11/11 [==============================] - 0s 29ms/step - loss: 1.9737 - accuracy: 0.4048 - val_loss: 4.3772 - val_accuracy: 0.1336
# Epoch 3/56
# 11/11 [==============================] - 0s 20ms/step - loss: 1.9713 - accuracy: 0.3921 - val_loss: 4.3329 - val_accuracy: 0.1221
# Epoch 4/56
# 11/11 [==============================] - 0s 18ms/step - loss: 1
56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.9563 - accuracy: 0.6980 - val_loss: 6.5150 - val_accuracy: 0.1374
# Epoch 33/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.8737 - accuracy: 0.7183 - val_loss: 6.5628 - val_accuracy: 0.1450
# Epoch 34/56
# 11/11 [==============================] - 0s 18ms/step - loss: 1.0262 - accuracy: 0.6992 - val_loss: 6.1803 - val_accuracy: 0.1756
# Epoch 35/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.9775 - accuracy: 0.6853 - val_loss: 6.0196 - val_accuracy: 0.1450
# Epoch 36/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.9631 - accuracy: 0.6878 - val_loss: 6.3007 - val_accuracy: 0.1641
# Epoch 37/56
# 11/11 [==============================] - 0s 19ms/step - loss: 0.8585 - accuracy: 0.7272 - val_loss: 6.1238 - val_accuracy: 0.1718
# Epoch 38/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.8332 - accuracy: 0.7475 - val_loss: 6.2646 - val_accuracy: 0.1565
# Epoch 39/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.8651 - accuracy: 0.7348 - val_loss: 6.4635 - val_accuracy: 0.1489
# Epoch 40/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.8335 - accuracy: 0.7424 - val_loss: 6.7742 - val_accuracy: 0.1450
# Epoch 41/56
# 11/11 [==============================] - 0s 19ms/step - loss: 0.8889 - accuracy: 0.7272 - val_loss: 6.1750 - val_accuracy: 0.1336
# Epoch 42/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.8866 - accuracy: 0.7132 - val_loss: 6.1425 - val_accuracy: 0.1412
# Epoch 43/56
# 11/11 [==============================] - 0s 17ms/step - loss: 0.7813 - accuracy: 0.7538 - val_loss: 6.7282 - val_accuracy: 0.1565
# Epoch 44/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.8377 - accuracy: 0.7386 - val_loss: 6.9699 - val_accuracy: 0.1298
# Epoch 45/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.7687 - accuracy: 0.7513 - val_loss: 6.6532 - val_accuracy: 0.1412
# Epoch 46/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.7455 - accuracy: 0.7766 - val_loss: 6.8768 - val_accuracy: 0.1641
# Epoch 47/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6654 - accuracy: 0.7970 - val_loss: 6.7399 - val_accuracy: 0.1450
# Epoch 48/56
# 11/11 [==============================] - 0s 19ms/step - loss: 0.7118 - accuracy: 0.7627 - val_loss: 7.3813 - val_accuracy: 0.1756
# Epoch 49/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6571 - accuracy: 0.7957 - val_loss: 6.8527 - val_accuracy: 0.1718
# Epoch 50/56
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6934 - accuracy: 0.7678 - val_loss: 6.9679 - val_accuracy: 0.1641
# Epoch 51/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.7920 - accuracy: 0.7589 - val_loss: 6.9273 - val_accuracy: 0.1374
# Epoch 52/56
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6663 - accuracy: 0.7970 - val_loss: 6.9535 - val_accuracy: 0.1565
# Epoch 53/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6533 - accuracy: 0.7957 - val_loss: 7.1353 - val_accuracy: 0.1374
# Epoch 54/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6562 - accuracy: 0.7970 - val_loss: 7.1788 - val_accuracy: 0.1374
# Epoch 55/56
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6143 - accuracy: 0.8249 - val_loss: 7.0690 - val_accuracy: 0.1565
# Epoch 56/56
# 11/11 [==============================] - 0s 18ms/step - loss: 0.5935 - accuracy: 0.8109 - val_loss: 7.1692 - val_accuracy: 0.1641

# %% [markdown]
# ## Visualize training results
#
# After applying data augmentation and `tf.keras.layers.Dropout`, there is less overfitting than before, and training and validation accuracy are closer aligned:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Predict on new data

# %%
sunflower_url = "https://wroom.ru/i2/carpic/38700.jpg"
sunflower_path = tf.keras.utils.get_file('Ford', origin=sunflower_url)

img = tf.keras.utils.load_img(
    sunflower_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# Downloading data from https://wroom.ru/i2/carpic/38700.jpg
# 565248/564856 [==============================] - 0s 0us/step
# 573440/564856 [==============================] - 0s 0us/step
# This image most likely belongs to Mitsubishi with a 98.95 percent confidence.
